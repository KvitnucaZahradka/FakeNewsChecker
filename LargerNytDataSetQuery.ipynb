# %%
from bs4 import BeautifulSoup as bs

import json
import re
import os
import time
import random
import datetime
import calendar
import logging

import urllib
import urllib.request

### RESOLVE THIS
from urllib.error import HTTPError

import requests
import html.parser
from requests.exceptions import HTTPError
from socket import error as SocketError
from http.cookiejar import CookieJar

import feedparser
import pickle


class NytData:
    # FIELDS
    __offset = 'offset=0'
    # you use just 9000 out of 10000 to have some buffer
    __totalNumberOfAllowedQueries = 9000
    __numberOfUsedQueries = 0
    __nytApiKey = ''
    __queryList = []
    __paperName = ''

    # CLASS INITIALIZATION
    def __init__(self, apiKey, paperName, totalNumberOfAllowedQueries=9000):
        try:
            ##  NOTE: add conditions to if statement
            if ((type(apiKey) and type(paperName)) == str):
                self.__nytApiKey = 'api-key=' + apiKey
                self.__paperName = paperName

                # add the required query list by hand
                self.__queryList = ["Politics", "Economics", "Business", "Financial", "World",
                                    "Washington", "Wealth", "Jobs", "Society"]
                # self.__queryList = queryList
                self.__totalNumberOfAllowedQueries = totalNumberOfAllowedQueries
            else:
                raise ValueError
        except ValueError as e:
            print('there has been error values in initialization')

    # HELPFUL FUNCTIONS (mostly private)

    ## this function constructs the Nytimes query, starting from some start date and end date and for some requested page
    def __constructUrlNytimes(self, queryList, startDate='20160901', endDate='20160930', page=0):

        apiUrl = 'http://api.nytimes.com/svc/search/v2/articlesearch.json?'

        query = 'fq=news_desk:('
        for iquery in queryList:
            query = query + '"' + iquery + '"'
        query += ')'
        apiUrl += query

        apiDate = 'begin_date=' + startDate + '&end_date=' + endDate + '&sort=newest' + "&page=" + str(page)

        link = [apiUrl, apiDate, self.__offset, self.__nytApiKey]
        reqUrl = '&'.join(link)
        return reqUrl

    ## function that constructs a feed
    def __constructFeed(self, reqUrl):
        try:
            ### prepare for opening
            req = urllib.request.Request(reqUrl, None)
            cj = CookieJar()
            opener = urllib.request.build_opener(urllib.request.HTTPCookieProcessor(cj))
            response = opener.open(req)
            raw_response = response.read()
            response.close()

            ### increase the number of used queries
            self.__numberOfUsedQueries += 1

            ### return the feed
            return json.loads(raw_response)
        except (urllib.request.HTTPError, HTTPError):
            print('some HTTPError')
            raise

    ## function that parse the feed and add it up to existing dictionary
    def __feedToDicParser(self, dictionary, feed):
        fake = False
        feed = feed['response']['docs']

        # this is the range the NYTimes gives you in one query
        for i in range(0, len(feed)):
            tempFeed = feed[i]
            idf = tempFeed['_id']
            dictionary[idf] = []

            # for security remember the id also in the body
            dictionary[idf].append(idf)
            # add whether source is fake or not a fake
            dictionary[idf].append(fake)
            # add publication date
            dictionary[idf].append(tempFeed['pub_date'])
            # add web-url
            dictionary[idf].append(tempFeed['web_url'])
            # add in a snippet
            dictionary[idf].append(tempFeed['snippet'])
            # add in an abstract
            dictionary[idf].append(tempFeed['abstract'])
        return dictionary

    ## function returns nyt snippets as a dictionary
    def __getNYTsnippets(self, queryList, startDate='20160901', endDate='20160931', upperBoundOnPages=10):
        dic = {}
        totalNumberOfErrors = 100
        numOfErrors = 0
        if ((upperBoundOnPages > self.__totalNumberOfAllowedQueries)
            or (self.__numberOfUsedQueries > self.__totalNumberOfAllowedQueries)):
            print('NYT upper bound exceeded returning empty dictionary ')
            return dic
        else:
            i = 0
            while i in range(0, upperBoundOnPages):
                try:
                    ### get the url
                    url = self.__constructUrlNytimes(queryList, startDate, endDate, page=i)
                    print(url)
                    ### get feed
                    feed = self.__constructFeed(url)
                    ### parse the feed and add it to dic
                    dic = self.__feedToDicParser(dic, feed)
                    print('DOING PAGE NR. :' + str(i))
                    i += 1
                    time.sleep(3)
                except (urllib.request.HTTPError, HTTPError):
                    if numOfErrors <= totalNumberOfErrors:
                        print('TOTAL NR. of ERRORS: ' + str(numOfErrors))
                        numOfErrors += 1
                        continue
                    else:
                        break
            return dic

    ## function that finds the url links in saved snippet dictionary
    ### if time allows add checker whether you are reading the NYT snippet dictionary
    def __findUrlLinks(self, nameOfDic):
        urlList = []
        dic = self.__safelyOpenDict(nameOfDic)
        for k in dic.keys():
            for idd in dic[k].keys():
                urlList.append(dic[k][idd][3])
        return urlList

    ## in this prune away 'video' section and 'slideshow' section in saved snippet dic.
    ## reason is too little text in there
    ### if time allows add checker whether you are reading the NYT snippet dictionary
    def __findUrlLinksPruned(self, nameOfDic):
        urlList = []
        dic = self.__safelyOpenDict(nameOfDic)
        for k in dic.keys():
            for idd in dic[k].keys():
                tempLink = dic[k][idd][3]
                if not (('video' in tempLink) or ('slideshow' in tempLink)):
                    urlList.append(dic[k][idd][3])
        return urlList

    ## in this prune away 'video' section and 'slideshow' section in saved snippet dic.
    ## reason is too little text in there
    ### if time allows add checker whether you are reading the NYT snippet dictionary
    def __findUrlLinksPrunedDictionary(self, nameOfDic):
        urlListDict = {}
        dic = self.__safelyOpenDict(nameOfDic)
        for k in dic.keys():
            for idd in dic[k].keys():
                tempLink = dic[k][idd][3]
                if not (('video' in tempLink) or ('slideshow' in tempLink)):
                    urlListDict[idd] = dic[k][idd][3]
        return urlListDict

    ## function that forces system to wait random time, with upper bound on wait equals to maxTime
    def __waitRandomTime(self, maxTime=7):
        ## setting up the seed
        tm = int(round(time.time()))
        random.seed(tm)

        tim = random.randint(0, 8 * 100) / 100.0
        time.sleep(tim)

    ## SAVING and ADD/DEL FUNCTIONS

    ### adds up two dictionaries and updates the first one to conglomerate
    def __addDict(self, final, temp):
        z = dict(final, **temp)
        final.update(z)

    ### creates an empty dictionary
    def __createEmptyDict(self, name_of_dictionary):
        with open(name_of_dictionary + '.pickle', 'wb') as handle:
            pickle.dump({}, handle)

    ###  opens the dictionary from file, if file is not present it creates is
    def __openDict(self, name_of_saved_dictionary):
        try:
            with open(name_of_saved_dictionary + '.pickle', 'rb') as handle:
                return pickle.load(handle)
        except FileNotFoundError:
            print("File was not found, I will create empty dictionary with name " + name_of_saved_dictionary)
            self.__createEmptyDict(name_of_saved_dictionary)
            return self.__openDict(name_of_saved_dictionary)

    ### save list to file
    def __saveList(self, listToSave, nameOfList):
        if (nameOfList + '.pickle') not in os.listdir():
            with open(nameOfList + '.pickle', 'wb') as handle:
                pickle.dump(listToSave, handle)
            print('List was saved under name ' + nameOfList + '.pickle')
        else:
            print('ERROR: the name ' + nameOfList + '.pickle has been used, use different one!')

    ### saves dictionary to file
    def __saveDictToFile(self, dictionary, name):
        with open(name + '.pickle', 'wb') as handle:
            pickle.dump(dictionary, handle)

    ### saving function that saves the dictionary and if not such a dictionary is present on disc will create it
    def __saveDict(self, dictionary, name_of_dictionary, start_of_the_month):

        # I will try to open a dictionary
        tempDic = self.__openDict(name_of_dictionary)

        # add a dictionary to current dictionary if it was not there
        if start_of_the_month not in tempDic.keys():
            addThisDic = {}
            addThisDic[start_of_the_month] = dictionary
            self.__addDict(tempDic, addThisDic)

            # saving dictionary into the file
            self.__saveDictToFile(tempDic, name_of_dictionary)
        else:
            print('the month ' + start_of_the_month + ' has been found in dictionary ' + name_of_dictionary)

    ### safely open the dictionary from file
    def __safelyOpenDict(self, nameOfSavedDictionary):
        try:
            with open(nameOfSavedDictionary + '.pickle', 'rb') as handle:
                return pickle.load(handle)
        except FileNotFoundError:
            print("File was not found ")

    ### deleting a key from a dictionary
    def __delPartKey(self, key, nameOfDic):
        dic = self.__safelyOpenDict(nameOfDic)

        if key in dic.keys():
            del (dic[key])

        self.__saveDictToFile(dic, nameOfDic)

    ## SCRAPING functions

    ## function that scrapes another link
    ### add checkers whether types are matching
    def __findAllInBs(self, beautifulSoup, textClass, itemprop=False, p='p'):
        text = ''
        if itemprop:
            for txt in beautifulSoup.find_all(p, class_=textClass, itemprop="articleBody"):
                text = text + ' ' + txt.text
            return text
        else:
            for txt in beautifulSoup.find_all(p, class_=textClass):
                text = text + ' ' + txt.text
            return text

    ## function that extract text, for Nytimes we have several classes of the text
    def __extractText(self, beautifulSoup, textClass=1):
        text = ''
        if textClass == 1:
            cls = "story-body-text"
            return self.__findAllInBs(beautifulSoup, cls, itemprop=True)
        elif textClass == 2:
            cls = "story-body-text story-content"
            return self.__findAllInBs(beautifulSoup, cls)
        elif textClass == 3:
            ### seems to be valid for video section, that I pruned away
            cls = "content-description"
            return self.__findAllInBs(beautifulSoup, cls)

    ## function that removes some garbage from the text
    def __removeTextGarbage(self, text, textClass=1):
        if textClass == 1:
            text = re.sub('\n', ' ', text)
            text = text.split('.')
            # get rid of two last sentences for text from textClass=1
            del (text[-1])
            del (text[-1])
            # join the text back to pre-cleaned text
            text = '. '.join(text)
            text += '.'
            return text

    ## function that finds a missing part of dictionary B in dictionary A
    def __findMissingDic(self, dicA, dicB):
        tempDic = {}
        for key in dicB.keys():
            if key not in dicA.keys():
                self.__addDict(tempDic, {key: dicB[key]})
        return tempDic

    ## this function adds and saves dictionaryToAdd to the saved dictionary called nameOfDictionary
    def __saveDictNytFullText(self, dictionaryToAdd, nameOfDictionary):

        # I will try to open a dictionary
        tempDic = self.__openDict(nameOfDictionary)

        # add a dictionary to current dictionary if it was not there
        # find Missing compares the two dictionaries and returns ids of all members of dictionary that
        # are not in tempDic
        missingIntempDic = self.__findMissingDic(tempDic, dictionaryToAdd)
        if len(missingIntempDic):
            print('adding some missing stuff to dictionary')
            self.__addDict(tempDic, missingIntempDic)

            # saving dictionary into the file
            self.__saveDictToFile(tempDic, nameOfDictionary)
        else:
            print('Everything seems to be already in the saved dictionary ' + nameOfDictionary + '.pickle')

    ## function retrieves the text and if necessary adds to a badLinkList, NOTICE NOTICE NOTICE this function depends
    ## on number of text classes you have
    def __getText(self, link, badLinkList, numberOfTextClasses):

        try:
            req = urllib.request.Request(link, None)
            cj = CookieJar()
            opener = urllib.request.build_opener(urllib.request.HTTPCookieProcessor(cj))
            response = opener.open(req)
            raw_response = response.read()
            response.close()

            bss = bs(raw_response, "html.parser")

            # this part is responsible for getting the nonzero text
            textClass = 1
            text = ''
            while textClass <= numberOfTextClasses:
                print(textClass)
                tempText = self.__extractText(bss, textClass=textClass)
                if len(tempText) > len(text):
                    text = tempText
                textClass += 1
            # if number of characters is smaller than 55 chars something is wrong, put link into the badLinkList
            if len(text) < 55:
                badLinkList.append(text)
                print('Check the bad link list, because there are ' + str(len(badLinkList)) + ' already ' +
                      'and one was just added! It is possible that there is another textClass among them or something else'
                      ' is not working properly.')
            return text

        except urllib.request.HTTPError as inst:
            output = format(inst)
            print(output)
            raise

    ## this function queries the NYT server, scrape the page and retrieve text, save it to: nameOfFile
    ## remember use the pruned dictionary
    def __downloadNytText(self, urlDic, nameOfFile):
        if (nameOfFile + '.pickle') in os.listdir():
            print(
                'ERROR: ALREADY USED name for requested file: ' + nameOfFile + '.pickle' + ',   USE different filename!')
        else:
            totalNumberOfErrors = 1000
            numberOfErrors = 0
            finalDic = {}
            badLinkList = []
            counter = 1

            ### we have to catch the HTTP errors
            for articleKey in urlDic.keys():
                try:
                    print('work in progress, step: ' + str(counter))
                    print('working on article with id: ' + articleKey)

                    # print(urlDic[articleKey])
                    text = self.__getText(urlDic[articleKey], badLinkList, 2)
                    # print(text)
                    counter += 1

                    if text != None and len(text) < 55:
                        print('continue')
                        continue
                    else:
                        finalDic[articleKey] = text

                    ## for sureness save it to disc immediately every 20 articles:
                    if (counter % 20) == 0:
                        self.__saveDictNytFullText(finalDic, nameOfFile)

                    ## waiting some random time to not be blocked (at least fast)
                    self.__waitRandomTime()

                except (urllib.request.HTTPError, HTTPError):
                    numberOfErrors += 1
                    print('ERROR nr. ' + str(numberOfErrors))
                    print('there was some HTTP error, it might be they have blocked you, '
                          'I will wait for some longer time and will query again')
                    print('I will do that until total number errors is smaller than ' + str(totalNumberOfErrors))

                    if numberOfErrors <= totalNumberOfErrors:
                        self.__waitRandomTime(15)
                        continue
                    else:
                        print('-----------END------BECAUSE---HTTP----ERROR---DID---NOT--STOP')
                        print('last article id was: ' + str(articleKey))
                except urllib.error.URLError as e:
                    print('URLError---URLError---URLError--URLError--URLError')
                    numberOfErrors += 1
                    print('ERROR nr. ' + str(numberOfErrors))
                    print('there was some HTTP error, it might be they have blocked you, '
                          'I will wait for some longer time and will query again')
                    print('I will do that until total number errors is smaller than ' + str(totalNumberOfErrors))

                    if numberOfErrors <= totalNumberOfErrors:
                        self.__waitRandomTime(15)
                        continue
                    else:
                        print('-----------END------BECAUSE---HTTP----ERROR---DID---NOT--STOP')
                        print('last article id was: ' + str(articleKey))

            ## saving what I have in final dic
            print('saving what I have in final dic ')
            self.__saveDictNytFullText(finalDic, nameOfFile)

            return badLinkList

    ## by this function you are getting the text from Nytimes, the year you are getting is dependent ONLY on
    ## the name of the dictionary nameOfUrlLinksDictionary
    def __getNytText(self, nameOfTextDictOnDisk, nameOfUrlLinksDictionary, year):

        ### creating the customary names
        nameOfTextDictOnDisk = nameOfTextDictOnDisk + str(year)
        nameOfUrlLinksDictionary = nameOfUrlLinksDictionary + str(year)

        urlDic = self.__findUrlLinksPrunedDictionary(nameOfUrlLinksDictionary)
        print('creating the url dictionary that is pruned')

        if len(urlDic) > 0:
            print('downloading the Nyt for the Url dictionary ' + nameOfUrlLinksDictionary)
            badLinkList = self.__downloadNytText(urlDic, nameOfTextDictOnDisk)
            if len(badLinkList) > 0:
                print('there are some links that have not been turned into text see saved badLinkList for current year')
                self.__saveList(badLinkList, ('badLinkList' + str(year)))
            else:
                print('everything seems to be turned into text check results saved in: ' + nameOfTextDictOnDisk)
        else:
            print('CHECK: for some reason the created urlDic is empty')

    ## querying through months
    def __queryThroughMonths(self, queryList, year=2016):
        for month in range(1, 13):
            try:
                print('dealing with month nr.: ' + str(month))
                rang = calendar.monthrange(year, month)
                start = datetime.date(year=year, month=month, day=1).strftime("%Y%m%d")
                end = datetime.date(year=year, month=month, day=rang[1]).strftime("%Y%m%d")

                docName = 'nytSnippets' + str(year)
                if (docName + '.pickle') in os.listdir():
                    temp = self.__safelyOpenDict(docName)

                    if start not in temp.keys():
                        dic = self.__getNYTsnippets(queryList, startDate=start, endDate=end)
                        self.__saveDict(dic, docName, start)
                    else:
                        print('skipping month ' + start + ' because already in database')
                else:
                    dic = self.__getNYTsnippets(queryList, startDate=start, endDate=end)
                    self.__saveDict(dic, docName, start)

                print('finished and saved month nr.: ' + str(month) + 'for year :' + str(year))

            except (urllib.request.HTTPError, HTTPError):
                #logging.error("HTTPError: with code: %s and with reason: %s", e.code, e.reason)
                print('there was some error in month ' + str(month) + ' see the logs')
                continue

    ### !!!!!!!!!!------->>>>>> NOTE NOTE NOTE not tested function

    ## final function that allows you to get data between years startYear and endYear
    def getDataNytimes(self, startYear, endYear):
        ### looping through the years
        for year in range(startYear, endYear + 1):

            ### if number of queries is bigger than total number of queries allowed bail
            if self.__numberOfUsedQueries > self.__totalNumberOfAllowedQueries:
                break
            else:
                try:
                    print('START querying the year: ' + str(year))
                    print('TOTAL number of queries used: ' + str(self.__numberOfUsedQueries))

                    ### this queries through months and saves result
                    self.__queryThroughMonths(self.__queryList, year)

                    nameOfSnippetDictionary = 'nytSnippets' + str(year)
                    print('FINISHED querying for the year: ' + str(year) + 'checking whether you have file: '
                          + nameOfSnippetDictionary + '.pickle saved in directory')

                    if (nameOfSnippetDictionary + '.pickle') in os.listdir():
                        print(nameOfSnippetDictionary + '.pickle is in directory')
                        print('everything seems to be OK')
                    else:
                        print('ERROR:' + nameOfSnippetDictionary + '.pickle was NOT found directory')
                        break

                    ### in this part you creates the pruned dictionary to be used in actual downloading of the data
                    ### this is for current year
                    dicToDownload = self.__findUrlLinksPrunedDictionary(nameOfSnippetDictionary)

                    ### downloading the dicToDownload
                    print('starting to download the text for year: ' + str(year))

                    print('first check whether you already do not have the file on disc if yes skip and report')
                    nameOfRawTextDictionary = 'nytRawText' + str(year) + '.pickle'

                    if nameOfRawTextDictionary not in os.listdir():
                        print('the raw text dictionary with name: ' + nameOfRawTextDictionary + '.pickle' +
                              ' has not been found on local drive. I will proceed to download it.')
                        badLinkList = self.__getNytText('nytRawText', 'nytSnippets', year)
                        print('stopped the text download for year ' + str(year))
                    else:
                        print('the raw text dictionary with name: ' + nameOfRawTextDictionary + '.pickle' +
                              ' HAS BEEN found on local drive. I will NOT download it.')
                        print('please check whether you have everything you wanted in ' +
                              nameOfRawTextDictionary + '.pickle')

                    ### checking whether you have saved at least something on disc
                    if nameOfRawTextDictionary not in os.listdir():
                        print('the raw text dictionary with name: ' + nameOfRawTextDictionary + '.pickle' +
                              ' has not been found on local drive. I will proceed to download it.')

                    else:
                        print('the raw text dictionary with name: ' + nameOfRawTextDictionary + '.pickle' +
                              ' HAS BEEN found on local drive. SOMETHING is wrong!!!!')
                        break


                        ### waiting some random time in order not to be blocked or at least not that fast
                except (urllib.request.HTTPError, HTTPError):
                    #logging.error("HTTPError: with code: %s and with reason: %s", e.code, e.reason)
                    print('there was HTTP error ' + ' see the logs')
                    continue
        return badLinkList

# %%
## try tu query using NytData
apiKey = '923f498f9f764c228a68501cf957355b'

# %%
dataBigger = NytData(apiKey, 'Nytimes', 7000)

# %%
dataBigger.getDataNytimes(2015, 2016)
# Out:
# START querying the year: 2015
# TOTAL number of queries used: 0
# dealing with month nr.: 1
# skipping month 20150101 because already in database
# finished and saved month nr.: 1for year :2015
# dealing with month nr.: 2
# skipping month 20150201 because already in database
# finished and saved month nr.: 2for year :2015
# dealing with month nr.: 3
# skipping month 20150301 because already in database
# finished and saved month nr.: 3for year :2015
# dealing with month nr.: 4
# skipping month 20150401 because already in database
# finished and saved month nr.: 4for year :2015
# dealing with month nr.: 5
# skipping month 20150501 because already in database
# finished and saved month nr.: 5for year :2015
# dealing with month nr.: 6
# skipping month 20150601 because already in database
# finished and saved month nr.: 6for year :2015
# dealing with month nr.: 7
# skipping month 20150701 because already in database
# finished and saved month nr.: 7for year :2015
# dealing with month nr.: 8
# skipping month 20150801 because already in database
# finished and saved month nr.: 8for year :2015
# dealing with month nr.: 9
# skipping month 20150901 because already in database
# finished and saved month nr.: 9for year :2015
# dealing with month nr.: 10
# skipping month 20151001 because already in database
# finished and saved month nr.: 10for year :2015
# dealing with month nr.: 11
# skipping month 20151101 because already in database
# finished and saved month nr.: 11for year :2015
# dealing with month nr.: 12
# skipping month 20151201 because already in database
# finished and saved month nr.: 12for year :2015
# FINISHED querying for the year: 2015checking whether you have file: nytSnippets2015.pickle saved in directory
# nytSnippets2015.pickle is in directory
# everything seems to be OK
# starting to download the text for year: 2015
# first check whether you already do not have the file on disc if yes skip and report
# the raw text dictionary with name: nytRawText2015.pickle.pickle has not been found on local drive. I will proceed to download it.
# creating the url dictionary that is pruned
# downloading the Nyt for the Url dictionary nytSnippets2015
# work in progress, step: 1
# working on article with id: 54cd5f0e38f0d84f1924fe7d
# 1
# 2
# work in progress, step: 2
# working on article with id: 54cd34c038f0d84f1924fe3c
# 1
# 2
# work in progress, step: 3
# working on article with id: 54cd0a7038f0d84f1924fdd4
# 1
# 2
# work in progress, step: 4
# working on article with id: 54cc45ca38f0d817610376a0
# 1
# 2
# work in progress, step: 5
# working on article with id: 54cc3afe38f0d8176103768a
# 1
# 2
# work in progress, step: 6
# working on article with id: 54cc375c38f0d81761037682
# 1
# 2
# work in progress, step: 7
# working on article with id: 54cc32b638f0d81761037679
# 1
# 2
# work in progress, step: 8
# working on article with id: 54cc2fa438f0d81761037674
# 1
# 2
# work in progress, step: 9
# working on article with id: 54cc2f0738f0d81761037672
# 1
# 2
# work in progress, step: 10
# working on article with id: 54f248da38f0d8529ba34a1a
# 1
# 2
# work in progress, step: 11
# working on article with id: 54f211e638f0d8529ba34990
# 1
# 2
# work in progress, step: 12
# working on article with id: 54f1f45e38f0d8529ba34947
# 1
# 2
# work in progress, step: 13
# working on article with id: 54f236b938f0d8529ba349f0
# 1
# 2
# work in progress, step: 14
# working on article with id: 54f140c238f0d8597ba1e587
# 1
# 2
# work in progress, step: 15
# working on article with id: 54f13fcb38f0d8597ba1e586
# 1
# 2
# work in progress, step: 16
# working on article with id: 54f1388b38f0d8597ba1e568
# 1
# 2
# work in progress, step: 17
# working on article with id: 54f12fa138f0d8597ba1e553
# 1
# 2
# work in progress, step: 18
# working on article with id: 54f1206c38f0d8597ba1e531
# 1
# 2
# work in progress, step: 19
# working on article with id: 54f1149138f0d8597ba1e515
# 1
# 2
# File was not found, I will create empty dictionary with name nytRawText2015
# adding some missing stuff to dictionary
# work in progress, step: 20
# working on article with id: 551b516a38f0d8521519e0c3
# 1
# 2
# work in progress, step: 21
# working on article with id: 551b32d238f0d8521519e079
# 1
# 2
# work in progress, step: 22
# working on article with id: 551b2adc38f0d8521519e05d
# 1
# 2
# work in progress, step: 23
# working on article with id: 551ac98438f0d8521519def3
# 1
# 2
# Check the bad link list, because there are 1 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 24
# working on article with id: 551ae1d938f0d8521519df50
# 1
# 2
# work in progress, step: 25
# working on article with id: 551ad9ca38f0d8521519df2e
# 1
# 2
# work in progress, step: 26
# working on article with id: 551a71d438f0d80a0e8bc89b
# 1
# 2
# work in progress, step: 27
# working on article with id: 551a1cc238f0d80a0e8bc7b7
# 1
# 2
# work in progress, step: 28
# working on article with id: 551b0fb438f0d8521519e00c
# 1
# 2
# Check the bad link list, because there are 2 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 29
# working on article with id: 551a007e38f0d80a0e8bc77c
# 1
# 2
# work in progress, step: 30
# working on article with id: 5519fc0838f0d80a0e8bc774
# 1
# 2
# work in progress, step: 31
# working on article with id: 5519e47238f0d80a0e8bc74c
# 1
# 2
# work in progress, step: 32
# working on article with id: 5519e43f38f0d80a0e8bc749
# 1
# 2
# work in progress, step: 33
# working on article with id: 5519e34238f0d80a0e8bc746
# 1
# 2
# work in progress, step: 34
# working on article with id: 5519dd4b38f0d80a0e8bc737
# 1
# 2
# work in progress, step: 35
# working on article with id: 5519d3af38f0d80a0e8bc723
# 1
# 2
# work in progress, step: 36
# working on article with id: 5519b96b38f0d80a0e8bc6cc
# 1
# 2
# work in progress, step: 37
# working on article with id: 5519b14538f0d80a0e8bc6a5
# 1
# 2
# work in progress, step: 38
# working on article with id: 5519a14b38f0d80a0e8bc655
# 1
# 2
# work in progress, step: 39
# working on article with id: 5519981338f0d80a0e8bc635
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 40
# working on article with id: 5519931538f0d80a0e8bc617
# 1
# 2
# work in progress, step: 41
# working on article with id: 55198eea38f0d80a0e8bc604
# 1
# 2
# work in progress, step: 42
# working on article with id: 55198e6338f0d80a0e8bc603
# 1
# 2
# work in progress, step: 43
# working on article with id: 55198cc238f0d80a0e8bc5fe
# 1
# 2
# work in progress, step: 44
# working on article with id: 5542de9f38f0d83d46e51f20
# 1
# 2
# work in progress, step: 45
# working on article with id: 5542cb8f38f0d83d46e51eee
# 1
# 2
# work in progress, step: 46
# working on article with id: 5542063d38f0d81c154895ad
# 1
# 2
# work in progress, step: 47
# working on article with id: 5541a90f38f0d81c1548949b
# 1
# 2
# work in progress, step: 48
# working on article with id: 55419ec638f0d81c1548948e
# 1
# 2
# work in progress, step: 49
# working on article with id: 55418cf038f0d81c1548945d
# 1
# 2
# work in progress, step: 50
# working on article with id: 5541843438f0d81c1548944d
# 1
# 2
# work in progress, step: 51
# working on article with id: 55417af938f0d81c1548943a
# 1
# 2
# work in progress, step: 52
# working on article with id: 5541780c38f0d81c15489431
# 1
# 2
# work in progress, step: 53
# working on article with id: 55416e3038f0d81c15489417
# 1
# 2
# work in progress, step: 54
# working on article with id: 55416bd238f0d81c15489411
# 1
# 2
# work in progress, step: 55
# working on article with id: 554166b338f0d81c15489400
# 1
# 2
# work in progress, step: 56
# working on article with id: 5541569538f0d81c154893d3
# 1
# 2
# work in progress, step: 57
# working on article with id: 554155c638f0d81c154893cc
# 1
# 2
# work in progress, step: 58
# working on article with id: 5541494e38f0d81c154893a2
# 1
# 2
# work in progress, step: 59
# working on article with id: 5541451438f0d81c15489397
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 60
# working on article with id: 554143cd38f0d81c15489394
# 1
# 2
# work in progress, step: 61
# working on article with id: 55413e4338f0d81c1548937b
# 1
# 2
# work in progress, step: 62
# working on article with id: 55413e2c38f0d81c15489378
# 1
# 2
# work in progress, step: 63
# working on article with id: 55412aeb38f0d81c15489336
# 1
# 2
# work in progress, step: 64
# working on article with id: 5541279b38f0d81c1548932c
# 1
# 2
# work in progress, step: 65
# working on article with id: 55411d7a38f0d81c15489308
# 1
# 2
# work in progress, step: 66
# working on article with id: 5541155738f0d81c154892f0
# 1
# 2
# work in progress, step: 67
# working on article with id: 554110a938f0d81c154892df
# 1
# 2
# work in progress, step: 68
# working on article with id: 55410b7b38f0d81c154892c1
# 1
# 2
# work in progress, step: 69
# working on article with id: 554105ea38f0d81c154892ac
# 1
# 2
# work in progress, step: 70
# working on article with id: 5540fb0438f0d877377da422
# 1
# 2
# work in progress, step: 71
# working on article with id: 5540f5ba38f0d877377da40b
# 1
# 2
# work in progress, step: 72
# working on article with id: 5540f5a938f0d877377da409
# 1
# 2
# work in progress, step: 73
# working on article with id: 5540f49e38f0d877377da404
# 1
# 2
# work in progress, step: 74
# working on article with id: 5540f09438f0d877377da3f4
# 1
# 2
# work in progress, step: 75
# working on article with id: 5540ee5e38f0d877377da3ee
# 1
# 2
# work in progress, step: 76
# working on article with id: 5540e86038f0d877377da3d3
# 1
# 2
# work in progress, step: 77
# working on article with id: 5540e34538f0d877377da3be
# 1
# 2
# work in progress, step: 78
# working on article with id: 5540e32138f0d877377da3bd
# 1
# 2
# work in progress, step: 79
# working on article with id: 5540e31e38f0d877377da3bc
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 80
# working on article with id: 5540d45538f0d877377da388
# 1
# 2
# work in progress, step: 81
# working on article with id: 5540cf5838f0d877377da37a
# 1
# 2
# work in progress, step: 82
# working on article with id: 5540ceb438f0d877377da377
# 1
# 2
# work in progress, step: 83
# working on article with id: 5540ca5338f0d877377da36a
# 1
# 2
# work in progress, step: 84
# working on article with id: 5540c22c38f0d877377da356
# 1
# 2
# work in progress, step: 85
# working on article with id: 5540b68238f0d877377da329
# 1
# 2
# work in progress, step: 86
# working on article with id: 5540b38c38f0d877377da322
# 1
# 2
# work in progress, step: 87
# working on article with id: 5540a24438f0d877377da2db
# 1
# 2
# work in progress, step: 88
# working on article with id: 5540956538f0d877377da29d
# 1
# 2
# work in progress, step: 89
# working on article with id: 55408a5738f0d877377da27a
# 1
# 2
# work in progress, step: 90
# working on article with id: 5540c7cc38f0d877377da360
# 1
# 2
# work in progress, step: 91
# working on article with id: 5540578f38f0d877377da1ef
# 1
# 2
# work in progress, step: 92
# working on article with id: 5540440038f0d877377da1b3
# 1
# 2
# work in progress, step: 93
# working on article with id: 55403b7538f0d877377da19f
# 1
# 2
# work in progress, step: 94
# working on article with id: 5540237738f0d877377da177
# 1
# 2
# work in progress, step: 95
# working on article with id: 5540234b38f0d877377da176
# 1
# 2
# work in progress, step: 96
# working on article with id: 554022cf38f0d877377da173
# 1
# 2
# work in progress, step: 97
# working on article with id: 554020ad38f0d877377da16e
# 1
# 2
# work in progress, step: 98
# working on article with id: 55401e9b38f0d877377da166
# 1
# 2
# work in progress, step: 99
# working on article with id: 55401e8438f0d877377da165
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 100
# working on article with id: 55401deb38f0d877377da163
# 1
# 2
# work in progress, step: 101
# working on article with id: 55400fc138f0d877377da143
# 1
# 2
# work in progress, step: 102
# working on article with id: 55400dfd38f0d877377da13e
# 1
# 2
# work in progress, step: 103
# working on article with id: 55400bce38f0d877377da138
# 1
# 2
# work in progress, step: 104
# working on article with id: 5540066c38f0d877377da12d
# 1
# 2
# work in progress, step: 105
# working on article with id: 5540026838f0d877377da11a
# 1
# 2
# work in progress, step: 106
# working on article with id: 553ff2f438f0d877377da0eb
# 1
# 2
# work in progress, step: 107
# working on article with id: 553ff10a38f0d877377da0df
# 1
# 2
# work in progress, step: 108
# working on article with id: 553ff0a338f0d877377da0dd
# 1
# 2
# work in progress, step: 109
# working on article with id: 553feda538f0d877377da0d2
# 1
# 2
# work in progress, step: 110
# working on article with id: 553fec3138f0d877377da0cc
# 1
# 2
# work in progress, step: 111
# working on article with id: 553fec0238f0d877377da0cb
# 1
# 2
# work in progress, step: 112
# working on article with id: 553feaf838f0d877377da0c8
# 1
# 2
# work in progress, step: 113
# working on article with id: 553fea9638f0d877377da0c7
# 1
# 2
# work in progress, step: 114
# working on article with id: 553fe7a838f0d877377da0ba
# 1
# 2
# work in progress, step: 115
# working on article with id: 553fde3038f0d877377da09e
# 1
# 2
# work in progress, step: 116
# working on article with id: 553fc6a838f0d877377da04d
# 1
# 2
# work in progress, step: 117
# working on article with id: 553fb73738f0d877377da018
# 1
# 2
# work in progress, step: 118
# working on article with id: 553fa8ba38f0d8592c70c459
# 1
# 2
# work in progress, step: 119
# working on article with id: 553f968438f0d8592c70c418
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 120
# working on article with id: 553f95bc38f0d8592c70c410
# 1
# 2
# work in progress, step: 121
# working on article with id: 553f91d338f0d8592c70c401
# 1
# 2
# work in progress, step: 122
# working on article with id: 553f8c2738f0d8592c70c3f0
# 1
# 2
# work in progress, step: 123
# working on article with id: 553f86ec38f0d8592c70c3e6
# 1
# 2
# work in progress, step: 124
# working on article with id: 553f84c938f0d8592c70c3dd
# 1
# 2
# work in progress, step: 125
# working on article with id: 553f835538f0d8592c70c3d5
# 1
# 2
# work in progress, step: 126
# working on article with id: 553f79c438f0d8592c70c3b1
# 1
# 2
# work in progress, step: 127
# working on article with id: 553f68b438f0d8592c70c378
# 1
# 2
# work in progress, step: 128
# working on article with id: 553f62c238f0d8592c70c366
# 1
# 2
# work in progress, step: 129
# working on article with id: 553f602d38f0d8592c70c35f
# 1
# 2
# work in progress, step: 130
# working on article with id: 553f4c5438f0d8592c70c327
# 1
# 2
# work in progress, step: 131
# working on article with id: 553f419438f0d8592c70c2f8
# 1
# 2
# work in progress, step: 132
# working on article with id: 556bb1b238f0d80ad152c8cf
# HTTP Error 410: Gone
# ERROR nr. 1
# there was some HTTP error, it might be they have blocked you, I will wait for some longer time and will query again
# I will do that until total number errors is smaller than 1000
# work in progress, step: 132
# working on article with id: 556b99a238f0d80ad152c8aa
# 1
# 2
# work in progress, step: 133
# working on article with id: 556b615e38f0d80ad152c850
# 1
# 2
# work in progress, step: 134
# working on article with id: 556ad4c438f0d87ed70a531b
# 1
# 2
# work in progress, step: 135
# working on article with id: 556a8ad238f0d87ed70a5296
# 1
# 2
# work in progress, step: 136
# working on article with id: 556a8ad438f0d87ed70a529d
# 1
# 2
# work in progress, step: 137
# working on article with id: 556a8ad238f0d87ed70a5295
# 1
# 2
# work in progress, step: 138
# working on article with id: 556a8ad438f0d87ed70a529e
# 1
# 2
# work in progress, step: 139
# working on article with id: 556a8ad938f0d87ed70a52a5
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 140
# working on article with id: 556a8ad938f0d87ed70a52a4
# 1
# 2
# work in progress, step: 141
# working on article with id: 556a8ae138f0d87ed70a52b0
# 1
# 2
# work in progress, step: 142
# working on article with id: 556a8ad338f0d87ed70a529a
# 1
# 2
# work in progress, step: 143
# working on article with id: 556a8ad638f0d87ed70a529f
# 1
# 2
# work in progress, step: 144
# working on article with id: 556a8adc38f0d87ed70a52aa
# 1
# 2
# work in progress, step: 145
# working on article with id: 556a8ad038f0d87ed70a5293
# 1
# 2
# work in progress, step: 146
# working on article with id: 556a8ad038f0d87ed70a5292
# 1
# 2
# work in progress, step: 147
# working on article with id: 556a8ad638f0d87ed70a52a0
# 1
# 2
# work in progress, step: 148
# working on article with id: 556a8adf38f0d87ed70a52ad
# 1
# 2
# work in progress, step: 149
# working on article with id: 556a8ad038f0d87ed70a5291
# 1
# 2
# work in progress, step: 150
# working on article with id: 556a8ad738f0d87ed70a52a2
# 1
# 2
# work in progress, step: 151
# working on article with id: 556a8ae138f0d87ed70a52ae
# 1
# 2
# work in progress, step: 152
# working on article with id: 556a8ae438f0d87ed70a52b1
# 1
# 2
# work in progress, step: 153
# working on article with id: 556a8ad038f0d87ed70a5290
# 1
# 2
# work in progress, step: 154
# working on article with id: 556a8ad738f0d87ed70a52a1
# 1
# 2
# work in progress, step: 155
# working on article with id: 556a8ade38f0d87ed70a52ac
# 1
# 2
# work in progress, step: 156
# working on article with id: 556a8ae138f0d87ed70a52af
# 1
# 2
# work in progress, step: 157
# working on article with id: 556a8ada38f0d87ed70a52a6
# 1
# 2
# work in progress, step: 158
# working on article with id: 556a8adc38f0d87ed70a52a7
# 1
# 2
# work in progress, step: 159
# working on article with id: 556a8add38f0d87ed70a52ab
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 160
# working on article with id: 556a8ad838f0d87ed70a52a3
# 1
# 2
# work in progress, step: 161
# working on article with id: 55934ab938f0d86249dfa66a
# 1
# 2
# work in progress, step: 162
# working on article with id: 559347c938f0d86249dfa663
# 1
# 2
# work in progress, step: 163
# working on article with id: 55931d0338f0d86249dfa60d
# 1
# 2
# work in progress, step: 164
# working on article with id: 559315bb38f0d86249dfa5ed
# 1
# 2
# work in progress, step: 165
# working on article with id: 5593116838f0d86249dfa5d6
# 1
# 2
# work in progress, step: 166
# working on article with id: 55930ef238f0d86249dfa5cd
# 1
# 2
# work in progress, step: 167
# working on article with id: 55930de738f0d86249dfa5c9
# 1
# 2
# work in progress, step: 168
# working on article with id: 5593091838f0d86249dfa5b5
# 1
# 2
# work in progress, step: 169
# working on article with id: 5593010138f0d86249dfa596
# 1
# 2
# Check the bad link list, because there are 3 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 170
# working on article with id: 5592f7bb38f0d86249dfa57b
# 1
# 2
# work in progress, step: 171
# working on article with id: 5592e82738f0d86249dfa539
# 1
# 2
# work in progress, step: 172
# working on article with id: 5592d5e538f0d86249dfa4ec
# 1
# 2
# work in progress, step: 173
# working on article with id: 5592cf6d38f0d86249dfa4d4
# 1
# 2
# work in progress, step: 174
# working on article with id: 5592cb1f38f0d86249dfa4ba
# 1
# 2
# work in progress, step: 175
# working on article with id: 5592c50238f0d86249dfa49a
# 1
# 2
# work in progress, step: 176
# working on article with id: 5592be7538f0d86249dfa480
# 1
# 2
# work in progress, step: 177
# working on article with id: 5592a8e138f0d846820c7b19
# 1
# 2
# work in progress, step: 178
# working on article with id: 5592a48b38f0d846820c7b09
# 1
# 2
# work in progress, step: 179
# working on article with id: 5592894138f0d846820c7aa1
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 180
# working on article with id: 5592778f38f0d846820c7a58
# 1
# 2
# work in progress, step: 181
# working on article with id: 5593fa7038f0d86249dfa896
# 1
# 2
# Check the bad link list, because there are 4 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 182
# working on article with id: 5592236038f0d846820c797d
# 1
# 2
# work in progress, step: 183
# working on article with id: 55bc289e38f0d847019fe64e
# 1
# 2
# work in progress, step: 184
# working on article with id: 55bbf25e38f0d847019fe5e5
# 1
# 2
# work in progress, step: 185
# working on article with id: 55bbefeb38f0d847019fe5de
# 1
# 2
# work in progress, step: 186
# working on article with id: 55bbee2638f0d847019fe5d9
# 1
# 2
# work in progress, step: 187
# working on article with id: 55bbd82438f0d847019fe58c
# 1
# 2
# work in progress, step: 188
# working on article with id: 55bbce0e38f0d847019fe56e
# 1
# 2
# work in progress, step: 189
# working on article with id: 55bbc68d38f0d847019fe552
# 1
# 2
# Check the bad link list, because there are 5 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 190
# working on article with id: 55bbc0ad38f0d847019fe541
# 1
# 2
# work in progress, step: 191
# working on article with id: 55bbbabf38f0d847019fe52d
# 1
# 2
# work in progress, step: 192
# working on article with id: 55bbb66438f0d847019fe518
# 1
# 2
# work in progress, step: 193
# working on article with id: 55bbb20838f0d847019fe4fd
# 1
# 2
# work in progress, step: 194
# working on article with id: 55bb8fec38f0d82ba98b937d
# 1
# 2
# work in progress, step: 195
# working on article with id: 55bb829738f0d82ba98b9346
# 1
# 2
# work in progress, step: 196
# working on article with id: 55bb816c38f0d82ba98b933f
# 1
# 2
# work in progress, step: 197
# working on article with id: 55bb79e438f0d82ba98b9322
# 1
# 2
# work in progress, step: 198
# working on article with id: 55bb720f38f0d82ba98b930a
# 1
# 2
# work in progress, step: 199
# working on article with id: 55bb392538f0d82ba98b924b
# 1
# 2
# Check the bad link list, because there are 6 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 200
# working on article with id: 55bb546638f0d82ba98b92a5
# 1
# 2
# work in progress, step: 201
# working on article with id: 55bac44838f0d82ba98b9160
# 1
# 2
# work in progress, step: 202
# working on article with id: 55bdea2838f0d8588a9d067e
# 1
# 2
# Check the bad link list, because there are 7 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 203
# working on article with id: 55bbbe6538f0d847019fe53b
# 1
# 2
# Check the bad link list, because there are 8 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 204
# working on article with id: 55bae3f738f0d82ba98b91a4
# 1
# 2
# work in progress, step: 205
# working on article with id: 55baebe738f0d82ba98b91c0
# 1
# 2
# work in progress, step: 206
# working on article with id: 55baddd838f0d82ba98b9197
# 1
# 2
# work in progress, step: 207
# working on article with id: 55bac8d838f0d82ba98b916b
# 1
# 2
# work in progress, step: 208
# working on article with id: 55bac64a38f0d82ba98b9165
# 1
# 2
# work in progress, step: 209
# working on article with id: 55bac5c738f0d82ba98b9163
# 1
# 2
# work in progress, step: 210
# working on article with id: 55bac1db38f0d82ba98b9158
# 1
# 2
# work in progress, step: 211
# working on article with id: 55bac0dc38f0d82ba98b9153
# 1
# 2
# work in progress, step: 212
# working on article with id: 55babf1c38f0d82ba98b914c
# 1
# 2
# work in progress, step: 213
# working on article with id: 55bab0c638f0d82ba98b9125
# 1
# 2
# work in progress, step: 214
# working on article with id: 55baa3f738f0d82ba98b910e
# 1
# 2
# work in progress, step: 215
# working on article with id: 55ba94e938f0d82ba98b90cf
# 1
# 2
# work in progress, step: 216
# working on article with id: 55ba8e0838f0d82ba98b90b6
# 1
# 2
# work in progress, step: 217
# working on article with id: 55ba8d0238f0d82ba98b90b2
# 1
# 2
# work in progress, step: 218
# working on article with id: 55ba8c7538f0d82ba98b90ac
# 1
# 2
# work in progress, step: 219
# working on article with id: 55ba8ac438f0d82ba98b90a7
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 220
# working on article with id: 55ba86e738f0d82ba98b9095
# 1
# 2
# work in progress, step: 221
# working on article with id: 55ba7fd638f0d82ba98b9077
# 1
# 2
# work in progress, step: 222
# working on article with id: 55ba7bb938f0d82ba98b9065
# 1
# 2
# work in progress, step: 223
# working on article with id: 55ba3f0438f0d810f56495f3
# 1
# 2
# work in progress, step: 224
# working on article with id: 55ba733438f0d82ba98b904b
# 1
# 2
# work in progress, step: 225
# working on article with id: 55ba6f3038f0d82ba98b9035
# 1
# 2
# work in progress, step: 226
# working on article with id: 55ba5e2f38f0d82ba98b9000
# 1
# 2
# work in progress, step: 227
# working on article with id: 55ba5e0a38f0d82ba98b8ffe
# 1
# 2
# work in progress, step: 228
# working on article with id: 55ba5cda38f0d82ba98b8ffb
# 1
# 2
# work in progress, step: 229
# working on article with id: 55ba564638f0d82ba98b8fdc
# 1
# 2
# work in progress, step: 230
# working on article with id: 55ba52fc38f0d82ba98b8fd5
# 1
# 2
# work in progress, step: 231
# working on article with id: 55ba4caf38f0d82ba98b8fbb
# 1
# 2
# work in progress, step: 232
# working on article with id: 55ba4b6f38f0d82ba98b8fb7
# 1
# 2
# work in progress, step: 233
# working on article with id: 55ba3c4f38f0d810f56495e5
# 1
# 2
# work in progress, step: 234
# working on article with id: 55ba351938f0d810f56495ca
# 1
# 2
# work in progress, step: 235
# working on article with id: 55ba349538f0d810f56495c8
# 1
# 2
# work in progress, step: 236
# working on article with id: 55ba302138f0d810f56495b6
# 1
# 2
# work in progress, step: 237
# working on article with id: 55ba2a0c38f0d810f56495a0
# 1
# 2
# work in progress, step: 238
# working on article with id: 55ba193238f0d810f5649575
# 1
# 2
# work in progress, step: 239
# working on article with id: 55ba13d538f0d810f564956b
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 240
# working on article with id: 55ba0cea38f0d810f564955b
# 1
# 2
# work in progress, step: 241
# working on article with id: 55ba0afd38f0d810f5649550
# 1
# 2
# work in progress, step: 242
# working on article with id: 55ba032338f0d810f5649537
# 1
# 2
# work in progress, step: 243
# working on article with id: 55b9f7c738f0d810f564951a
# 1
# 2
# work in progress, step: 244
# working on article with id: 55b9f4be38f0d810f5649511
# 1
# 2
# work in progress, step: 245
# working on article with id: 55b9f18f38f0d810f5649505
# 1
# 2
# work in progress, step: 246
# working on article with id: 55b9dec838f0d810f56494cf
# 1
# 2
# work in progress, step: 247
# working on article with id: 55b9dafa38f0d810f56494c9
# 1
# 2
# work in progress, step: 248
# working on article with id: 55b9d99138f0d810f56494c6
# 1
# 2
# work in progress, step: 249
# working on article with id: 55b9d41438f0d810f56494bb
# 1
# 2
# work in progress, step: 250
# working on article with id: 55bb38ea38f0d82ba98b9248
# 1
# 2
# Check the bad link list, because there are 9 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 251
# working on article with id: 55ba520038f0d82ba98b8fd1
# 1
# 2
# Check the bad link list, because there are 10 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 252
# working on article with id: 55b9858138f0d810f56493f3
# 1
# 2
# work in progress, step: 253
# working on article with id: 55b9851b38f0d810f56493f0
# 1
# 2
# work in progress, step: 254
# working on article with id: 55b9815a38f0d810f56493eb
# 1
# 2
# work in progress, step: 255
# working on article with id: 55b9804a38f0d810f56493ea
# 1
# 2
# work in progress, step: 256
# working on article with id: 55b97d7338f0d810f56493e8
# 1
# 2
# work in progress, step: 257
# working on article with id: 55b97b3638f0d810f56493e6
# 1
# 2
# work in progress, step: 258
# working on article with id: 55b97a6038f0d810f56493e3
# 1
# 2
# work in progress, step: 259
# working on article with id: 55b9794438f0d810f56493df
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 260
# working on article with id: 55b9793838f0d810f56493de
# 1
# 2
# work in progress, step: 261
# working on article with id: 55b9724038f0d810f56493d8
# 1
# 2
# work in progress, step: 262
# working on article with id: 55b96f2338f0d810f56493d3
# 1
# 2
# work in progress, step: 263
# working on article with id: 55b96c3138f0d810f56493ce
# 1
# 2
# work in progress, step: 264
# working on article with id: 55b9671938f0d810f56493c4
# 1
# 2
# work in progress, step: 265
# working on article with id: 55b9508038f0d810f5649394
# 1
# 2
# work in progress, step: 266
# working on article with id: 55b94d3f38f0d810f5649386
# 1
# 2
# work in progress, step: 267
# working on article with id: 55b9431238f0d810f564935c
# 1
# 2
# work in progress, step: 268
# working on article with id: 55e5075b38f0d8547fb3403a
# 1
# 2
# work in progress, step: 269
# working on article with id: 55e5019838f0d8547fb34036
# 1
# 2
# work in progress, step: 270
# working on article with id: 55e4d19438f0d8547fb33fce
# 1
# 2
# work in progress, step: 271
# working on article with id: 55e492ff38f0d8547fb33f1a
# 1
# 2
# work in progress, step: 272
# working on article with id: 55e4827c38f0d8547fb33eea
# 1
# 2
# work in progress, step: 273
# working on article with id: 55e47ab938f0d8547fb33ecf
# 1
# 2
# work in progress, step: 274
# working on article with id: 55e471db38f0d84c14715fa4
# 1
# 2
# work in progress, step: 275
# working on article with id: 55e4557b38f0d84c14715f65
# 1
# 2
# work in progress, step: 276
# working on article with id: 55e44b2e38f0d84c14715f48
# 1
# 2
# work in progress, step: 277
# working on article with id: 55e432bb38f0d84c14715f13
# 1
# 2
# work in progress, step: 278
# working on article with id: 55e475a838f0d84c14715fac
# 1
# 2
# work in progress, step: 279
# working on article with id: 55e3c2e538f0d84c14715e02
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 280
# working on article with id: 55e3a9b438f0d84c14715de4
# 1
# 2
# work in progress, step: 281
# working on article with id: 55e3a82c38f0d84c14715ddd
# 1
# 2
# work in progress, step: 282
# working on article with id: 55e3a7c238f0d84c14715dd9
# 1
# 2
# work in progress, step: 283
# working on article with id: 55e3a2d338f0d84c14715dcf
# 1
# 2
# work in progress, step: 284
# working on article with id: 55e3a08a38f0d84c14715dc8
# 1
# 2
# work in progress, step: 285
# working on article with id: 55e399e238f0d84c14715dbe
# 1
# 2
# work in progress, step: 286
# working on article with id: 55e392cb38f0d84c14715db6
# 1
# 2
# work in progress, step: 287
# working on article with id: 55e380e238f0d84c14715d99
# 1
# 2
# work in progress, step: 288
# working on article with id: 55e37d7e38f0d84c14715d91
# 1
# 2
# work in progress, step: 289
# working on article with id: 55e36ab138f0d84c14715d64
# 1
# 2
# work in progress, step: 290
# working on article with id: 55e34bae38f0d84c14715d41
# 1
# 2
# work in progress, step: 291
# working on article with id: 55e334c538f0d84c14715d25
# 1
# 2
# work in progress, step: 292
# working on article with id: 55e3122a38f0d84a4ed155a0
# 1
# 2
# work in progress, step: 293
# working on article with id: 55e2e09538f0d84a4ed1555c
# 1
# 2
# work in progress, step: 294
# working on article with id: 55e2e04538f0d84a4ed1555b
# 1
# 2
# work in progress, step: 295
# working on article with id: 55e289c638f0d84a4ed154d1
# 1
# 2
# work in progress, step: 296
# working on article with id: 55e2836e38f0d84a4ed154c8
# 1
# 2
# work in progress, step: 297
# working on article with id: 55e2836738f0d84a4ed154bf
# 1
# 2
# work in progress, step: 298
# working on article with id: 55e2835738f0d84a4ed154af
# 1
# 2
# work in progress, step: 299
# working on article with id: 55e2836638f0d84a4ed154be
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 300
# working on article with id: 55e2834d38f0d84a4ed154a9
# 1
# 2
# work in progress, step: 301
# working on article with id: 55e2835138f0d84a4ed154ac
# 1
# 2
# work in progress, step: 302
# working on article with id: 55e2835b38f0d84a4ed154b2
# 1
# 2
# work in progress, step: 303
# working on article with id: 55e2836038f0d84a4ed154b9
# 1
# 2
# work in progress, step: 304
# working on article with id: 55e2836c38f0d84a4ed154c5
# 1
# 2
# work in progress, step: 305
# working on article with id: 55e2834c38f0d84a4ed154a8
# 1
# 2
# work in progress, step: 306
# working on article with id: 55e2835b38f0d84a4ed154b3
# 1
# 2
# work in progress, step: 307
# working on article with id: 55e2836038f0d84a4ed154b8
# 1
# 2
# work in progress, step: 308
# working on article with id: 55e2836338f0d84a4ed154ba
# 1
# 2
# work in progress, step: 309
# working on article with id: 55e2836f38f0d84a4ed154ca
# 1
# 2
# work in progress, step: 310
# working on article with id: 55e2835b38f0d84a4ed154b4
# 1
# 2
# work in progress, step: 311
# working on article with id: 55e2835c38f0d84a4ed154b5
# 1
# 2
# work in progress, step: 312
# working on article with id: 55e2836038f0d84a4ed154b7
# 1
# 2
# work in progress, step: 313
# working on article with id: 55e2836438f0d84a4ed154bc
# 1
# 2
# work in progress, step: 314
# working on article with id: 55e2835438f0d84a4ed154ad
# 1
# 2
# work in progress, step: 315
# working on article with id: 55e2836438f0d84a4ed154bb
# 1
# 2
# work in progress, step: 316
# working on article with id: 55e2837238f0d84a4ed154cb
# 1
# 2
# work in progress, step: 317
# working on article with id: 55e2834a38f0d84a4ed154a7
# 1
# 2
# work in progress, step: 318
# working on article with id: 55e2836a38f0d84a4ed154c3
# 1
# 2
# work in progress, step: 319
# working on article with id: 55e2836b38f0d84a4ed154c4
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 320
# working on article with id: 55e2834a38f0d84a4ed154a6
# 1
# 2
# work in progress, step: 321
# working on article with id: 55e2834f38f0d84a4ed154aa
# 1
# 2
# work in progress, step: 322
# working on article with id: 55e2836a38f0d84a4ed154c2
# 1
# 2
# work in progress, step: 323
# working on article with id: 55e2834a38f0d84a4ed154a5
# 1
# 2
# work in progress, step: 324
# working on article with id: 55e2835638f0d84a4ed154ae
# 1
# 2
# work in progress, step: 325
# working on article with id: 55e2835d38f0d84a4ed154b6
# 1
# 2
# work in progress, step: 326
# working on article with id: 55e2836538f0d84a4ed154bd
# 1
# 2
# work in progress, step: 327
# working on article with id: 55e2836838f0d84a4ed154c0
# 1
# 2
# work in progress, step: 328
# working on article with id: 55e2836838f0d84a4ed154c1
# 1
# 2
# work in progress, step: 329
# working on article with id: 55e2835a38f0d84a4ed154b1
# 1
# 2
# work in progress, step: 330
# working on article with id: 55e2836d38f0d84a4ed154c6
# 1
# 2
# work in progress, step: 331
# working on article with id: 55e2835038f0d84a4ed154ab
# 1
# 2
# work in progress, step: 332
# working on article with id: 55e2835a38f0d84a4ed154b0
# 1
# 2
# work in progress, step: 333
# working on article with id: 55e2836d38f0d84a4ed154c7
# 1
# 2
# work in progress, step: 334
# working on article with id: 55e22bfd38f0d84a4ed15438
# 1
# 2
# work in progress, step: 335
# working on article with id: 55e213be38f0d84a4ed1540c
# 1
# 2
# work in progress, step: 336
# working on article with id: 55e211ce38f0d84a4ed15408
# 1
# 2
# work in progress, step: 337
# working on article with id: 55e1d78138f0d84a4ed153a4
# 1
# 2
# work in progress, step: 338
# working on article with id: 55e1ca2938f0d83605e15885
# 1
# 2
# work in progress, step: 339
# working on article with id: 55e1b3ed38f0d83605e15867
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 340
# working on article with id: 55e174bf38f0d83605e15818
# 1
# 2
# work in progress, step: 341
# working on article with id: 55e112e038f0d83605e15799
# 1
# 2
# work in progress, step: 342
# working on article with id: 55e0e72438f0d83605e15755
# 1
# 2
# work in progress, step: 343
# working on article with id: 55e0e5e938f0d83605e1574f
# 1
# 2
# work in progress, step: 344
# working on article with id: 55e0df9b38f0d83605e15741
# 1
# 2
# work in progress, step: 345
# working on article with id: 55e0da6b38f0d83605e15731
# 1
# 2
# work in progress, step: 346
# working on article with id: 55e0d71c38f0d83605e15724
# 1
# 2
# work in progress, step: 347
# working on article with id: 55e0d62838f0d83605e15720
# 1
# 2
# work in progress, step: 348
# working on article with id: 55e0d46438f0d83605e1571b
# 1
# 2
# Check the bad link list, because there are 11 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 349
# working on article with id: 55e0d30d38f0d83605e15717
# 1
# 2
# work in progress, step: 350
# working on article with id: 55e0ca4338f0d83605e156f9
# 1
# 2
# work in progress, step: 351
# working on article with id: 55e0bb3c38f0d83605e156cd
# 1
# 2
# work in progress, step: 352
# working on article with id: 55e0b65338f0d83605e156bd
# 1
# 2
# work in progress, step: 353
# working on article with id: 55e0ae4038f0d83605e156ab
# 1
# 2
# work in progress, step: 354
# working on article with id: 55e0ab5e38f0d83605e1569f
# 1
# 2
# work in progress, step: 355
# working on article with id: 55e0a2b538f0d83605e1568d
# 1
# 2
# work in progress, step: 356
# working on article with id: 55e09f3138f0d83605e15681
# 1
# 2
# work in progress, step: 357
# working on article with id: 560c944938f0d8716779a974
# 1
# 2
# work in progress, step: 358
# working on article with id: 560c8f5138f0d8716779a969
# 1
# 2
# work in progress, step: 359
# working on article with id: 560c86c338f0d8716779a951
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 360
# working on article with id: 560c82a738f0d8716779a94a
# 1
# 2
# work in progress, step: 361
# working on article with id: 560c727e38f0d8716779a919
# 1
# 2
# work in progress, step: 362
# working on article with id: 560c63d738f0d8716779a8ef
# 1
# 2
# work in progress, step: 363
# working on article with id: 560c5eef38f0d8716779a8e2
# 1
# 2
# work in progress, step: 364
# working on article with id: 560c581c38f0d8716779a8ba
# 1
# 2
# work in progress, step: 365
# working on article with id: 560c444e38f0d8716779a864
# 1
# 2
# work in progress, step: 366
# working on article with id: 560c400038f0d8716779a84f
# 1
# 2
# work in progress, step: 367
# working on article with id: 560c391038f0d8716779a82d
# 1
# 2
# work in progress, step: 368
# working on article with id: 560c290b38f0d8716779a7e1
# 1
# 2
# work in progress, step: 369
# working on article with id: 560c1c1f38f0d8716779a7a5
# 1
# 2
# work in progress, step: 370
# working on article with id: 560c115638f0d8716779a76e
# 1
# 2
# work in progress, step: 371
# working on article with id: 560c010a38f0d84e279914af
# 1
# 2
# work in progress, step: 372
# working on article with id: 560bdd2d38f0d84e27991402
# 1
# 2
# work in progress, step: 373
# working on article with id: 560bc96038f0d84e279913c7
# 1
# 2
# work in progress, step: 374
# working on article with id: 560be18538f0d84e2799140f
# 1
# 2
# work in progress, step: 375
# working on article with id: 560c825438f0d8716779a948
# 1
# 2
# Check the bad link list, because there are 12 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 376
# working on article with id: 560cac9e38f0d8716779a9a6
# 1
# 2
# Check the bad link list, because there are 13 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 377
# working on article with id: 560b426d38f0d84e2799125f
# 1
# 2
# work in progress, step: 378
# working on article with id: 560b429e38f0d84e27991260
# 1
# 2
# work in progress, step: 379
# working on article with id: 560b367338f0d84e2799124c
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 380
# working on article with id: 560b32b238f0d84e27991247
# 1
# 2
# work in progress, step: 381
# working on article with id: 560b2c9038f0d84e2799123a
# 1
# 2
# work in progress, step: 382
# working on article with id: 560b216638f0d84e27991222
# 1
# 2
# work in progress, step: 383
# working on article with id: 560b1cc738f0d84e27991217
# 1
# 2
# work in progress, step: 384
# working on article with id: 560b156538f0d84e27991202
# 1
# 2
# work in progress, step: 385
# working on article with id: 560b0e5138f0d84e279911f1
# 1
# 2
# work in progress, step: 386
# working on article with id: 560b09ae38f0d84e279911e3
# 1
# 2
# work in progress, step: 387
# working on article with id: 560b080d38f0d84e279911dd
# 1
# 2
# work in progress, step: 388
# working on article with id: 560b055738f0d84e279911d4
# 1
# 2
# work in progress, step: 389
# working on article with id: 560afd2938f0d84e279911ae
# 1
# 2
# work in progress, step: 390
# working on article with id: 560af61338f0d84e27991186
# 1
# 2
# work in progress, step: 391
# working on article with id: 560af44f38f0d84e2799117c
# 1
# 2
# work in progress, step: 392
# working on article with id: 560af15338f0d84e27991173
# 1
# 2
# work in progress, step: 393
# working on article with id: 560ae11838f0d84e2799112f
# 1
# 2
# work in progress, step: 394
# working on article with id: 560adf0638f0d84e27991128
# 1
# 2
# work in progress, step: 395
# working on article with id: 560adde938f0d84e27991122
# 1
# 2
# work in progress, step: 396
# working on article with id: 560adaae38f0d84e2799110d
# 1
# 2
# work in progress, step: 397
# working on article with id: 560ada5138f0d84e2799110c
# 1
# 2
# work in progress, step: 398
# working on article with id: 560ad78838f0d84e27991100
# 1
# 2
# work in progress, step: 399
# working on article with id: 560ad6c838f0d84e279910f9
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 400
# working on article with id: 560ad32d38f0d84e279910ed
# 1
# 2
# work in progress, step: 401
# working on article with id: 560ad14038f0d84e279910e8
# 1
# 2
# work in progress, step: 402
# working on article with id: 560ac07d38f0d84e279910a6
# 1
# 2
# work in progress, step: 403
# working on article with id: 560ab18938f0d82f96b485cf
# 1
# 2
# work in progress, step: 404
# working on article with id: 560aa7b338f0d82f96b4859f
# 1
# 2
# work in progress, step: 405
# working on article with id: 560aa28b38f0d82f96b4858e
# 1
# 2
# work in progress, step: 406
# working on article with id: 560a99f838f0d82f96b4856b
# 1
# 2
# work in progress, step: 407
# working on article with id: 560a939b38f0d82f96b48552
# 1
# 2
# work in progress, step: 408
# working on article with id: 560a929838f0d82f96b48551
# 1
# 2
# work in progress, step: 409
# working on article with id: 560a8bd438f0d82f96b4853a
# 1
# 2
# work in progress, step: 410
# working on article with id: 560a84a438f0d82f96b48525
# 1
# 2
# work in progress, step: 411
# working on article with id: 560a81c438f0d82f96b48520
# 1
# 2
# work in progress, step: 412
# working on article with id: 560a806d38f0d82f96b4851a
# 1
# 2
# work in progress, step: 413
# working on article with id: 560a6c8338f0d82f96b484e2
# 1
# 2
# work in progress, step: 414
# working on article with id: 560b5d6238f0d84e27991291
# 1
# 2
# Check the bad link list, because there are 14 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 415
# working on article with id: 560a3f4638f0d82f96b48465
# 1
# 2
# work in progress, step: 416
# working on article with id: 560a0d7a38f0d82f96b483ff
# 1
# 2
# work in progress, step: 417
# working on article with id: 560b16d638f0d84e27991203
# 1
# 2
# Check the bad link list, because there are 15 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 418
# working on article with id: 560afeda38f0d84e279911b7
# 1
# 2
# Check the bad link list, because there are 16 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 419
# working on article with id: 560af5a838f0d84e27991182
# 1
# 2
# Check the bad link list, because there are 17 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 420
# working on article with id: 5609f60738f0d82f96b483d7
# 1
# 2
# work in progress, step: 421
# working on article with id: 5609f11f38f0d82f96b483ce
# 1
# 2
# work in progress, step: 422
# working on article with id: 5609e59d38f0d82f96b483bb
# 1
# 2
# work in progress, step: 423
# working on article with id: 5609e46b38f0d82f96b483b7
# 1
# 2
# work in progress, step: 424
# working on article with id: 5609e24638f0d82f96b483b4
# 1
# 2
# work in progress, step: 425
# working on article with id: 5609e10d38f0d82f96b483b0
# 1
# 2
# work in progress, step: 426
# working on article with id: 5609df9f38f0d82f96b483aa
# 1
# 2
# work in progress, step: 427
# working on article with id: 5609dfa838f0d82f96b483ab
# 1
# 2
# work in progress, step: 428
# working on article with id: 5609df1438f0d82f96b483a8
# 1
# 2
# work in progress, step: 429
# working on article with id: 5609debe38f0d82f96b483a7
# 1
# 2
# work in progress, step: 430
# working on article with id: 560e737138f0d81aa77a53b2
# 1
# 2
# work in progress, step: 431
# working on article with id: 5609ddcc38f0d82f96b483a3
# 1
# 2
# work in progress, step: 432
# working on article with id: 5609dcfd38f0d82f96b483a0
# 1
# 2
# work in progress, step: 433
# working on article with id: 5609c68038f0d82f96b4837d
# 1
# 2
# work in progress, step: 434
# working on article with id: 5609c2e938f0d82f96b48378
# 1
# 2
# work in progress, step: 435
# working on article with id: 5609bef738f0d82f96b4836f
# 1
# 2
# work in progress, step: 436
# working on article with id: 5609be1838f0d82f96b4836c
# 1
# 2
# work in progress, step: 437
# working on article with id: 5609bd4138f0d82f96b4836a
# 1
# 2
# work in progress, step: 438
# working on article with id: 5609bb4f38f0d82f96b48362
# 1
# 2
# work in progress, step: 439
# working on article with id: 5609b5c338f0d82f96b48349
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 440
# working on article with id: 56353a7d38f0d87d1a1ab6a5
# 1
# 2
# work in progress, step: 441
# working on article with id: 5634f35a38f0d87d1a1ab619
# 1
# 2
# work in progress, step: 442
# working on article with id: 5634b01e38f0d85e68a21fa1
# 1
# 2
# work in progress, step: 443
# working on article with id: 5634e5e138f0d87d1a1ab605
# 1
# 2
# work in progress, step: 444
# working on article with id: 5634e1e338f0d85e68a21ffc
# 1
# 2
# work in progress, step: 445
# working on article with id: 5634ae6838f0d85e68a21f9f
# 1
# 2
# Check the bad link list, because there are 18 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 446
# working on article with id: 5634211b38f0d85e68a21ec8
# 1
# 2
# work in progress, step: 447
# working on article with id: 563419c838f0d85e68a21eb3
# 1
# 2
# work in progress, step: 448
# working on article with id: 563418b138f0d85e68a21eab
# 1
# 2
# work in progress, step: 449
# working on article with id: 5634172c38f0d85e68a21ea8
# 1
# 2
# work in progress, step: 450
# working on article with id: 563403cb38f0d85e68a21e8a
# 1
# 2
# work in progress, step: 451
# working on article with id: 5633ff7b38f0d85e68a21e7f
# 1
# 2
# work in progress, step: 452
# working on article with id: 5633ff8038f0d85e68a21e80
# 1
# 2
# Check the bad link list, because there are 19 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 453
# working on article with id: 5633f87738f0d85e68a21e72
# 1
# 2
# work in progress, step: 454
# working on article with id: 5633f35938f0d85e68a21e67
# 1
# 2
# work in progress, step: 455
# working on article with id: 5633edca38f0d85e68a21e56
# 1
# 2
# work in progress, step: 456
# working on article with id: 5633ead938f0d85e68a21e49
# 1
# 2
# work in progress, step: 457
# working on article with id: 5633e61e38f0d85e68a21e3d
# 1
# 2
# work in progress, step: 458
# working on article with id: 5633d88f38f0d85e68a21df4
# 1
# 2
# work in progress, step: 459
# working on article with id: 5633ca8138f0d85e68a21dc1
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 460
# working on article with id: 5633c06f38f0d85e68a21d9b
# 1
# 2
# work in progress, step: 461
# working on article with id: 5633be7038f0d85e68a21d93
# 1
# 2
# work in progress, step: 462
# working on article with id: 5633be0238f0d85e68a21d92
# 1
# 2
# work in progress, step: 463
# working on article with id: 5633bc5e38f0d85e68a21d8a
# 1
# 2
# work in progress, step: 464
# working on article with id: 5633b9dd38f0d85e68a21d7c
# 1
# 2
# work in progress, step: 465
# working on article with id: 5633b8a238f0d85e68a21d77
# 1
# 2
# work in progress, step: 466
# working on article with id: 5633b77138f0d85e68a21d71
# 1
# 2
# work in progress, step: 467
# working on article with id: 5633af5838f0d85e68a21d4a
# 1
# 2
# work in progress, step: 468
# working on article with id: 5633ad8e38f0d85e68a21d44
# 1
# 2
# work in progress, step: 469
# working on article with id: 5633a6fb38f0d85e68a21d28
# 1
# 2
# work in progress, step: 470
# working on article with id: 56339f6238f0d85e68a21d0c
# 1
# 2
# work in progress, step: 471
# working on article with id: 56339e1938f0d85e68a21d02
# 1
# 2
# work in progress, step: 472
# working on article with id: 56339beb38f0d85e68a21cf6
# 1
# 2
# work in progress, step: 473
# working on article with id: 56339af038f0d85e68a21cee
# 1
# 2
# work in progress, step: 474
# working on article with id: 5633938638f0d8310a2a08f3
# 1
# 2
# work in progress, step: 475
# working on article with id: 56337e5638f0d8310a2a0882
# 1
# 2
# work in progress, step: 476
# working on article with id: 5633785938f0d8310a2a086a
# 1
# 2
# work in progress, step: 477
# working on article with id: 563371bd38f0d8310a2a0850
# 1
# 2
# work in progress, step: 478
# working on article with id: 563370be38f0d8310a2a084a
# 1
# 2
# work in progress, step: 479
# working on article with id: 5633683238f0d8310a2a082b
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 480
# working on article with id: 56334d4538f0d8310a2a07cd
# 1
# 2
# work in progress, step: 481
# working on article with id: 5633472c38f0d8310a2a07be
# 1
# 2
# work in progress, step: 482
# working on article with id: 563344b538f0d8310a2a07b7
# 1
# 2
# work in progress, step: 483
# working on article with id: 5633406038f0d8310a2a07a4
# 1
# 2
# work in progress, step: 484
# working on article with id: 56333f8f38f0d8310a2a07a0
# 1
# 2
# work in progress, step: 485
# ...
# working on article with id: 563257f838f0d8310a2a049c
# 1
# 2
# work in progress, step: 515
# working on article with id: 56324e9c38f0d8310a2a0474
# 1
# 2
# work in progress, step: 516
# working on article with id: 56324cdd38f0d8310a2a0470
# 1
# 2
# work in progress, step: 517
# working on article with id: 56324cbf38f0d8310a2a046f
# 1
# 2
# work in progress, step: 518
# working on article with id: 56324bf638f0d8310a2a046a
# 1
# 2
# work in progress, step: 519
# working on article with id: 565d237838f0d83cebcef363
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 520
# working on article with id: 565d0df038f0d83cebcef333
# 1
# 2
# work in progress, step: 521
# working on article with id: 565d0b9438f0d83cebcef32b
# 1
# 2
# work in progress, step: 522
# working on article with id: 565ccc4d38f0d83cebcef29d
# 1
# 2
# work in progress, step: 523
# working on article with id: 565cc0cd38f0d83cebcef27b
# 1
# 2
# work in progress, step: 524
# working on article with id: 565ca9b638f0d83cebcef225
# 1
# 2
# work in progress, step: 525
# working on article with id: 565c96bd38f0d83cebcef1da
# 1
# 2
# work in progress, step: 526
# working on article with id: 565c867138f0d83cebcef1a8
# 1
# 2
# work in progress, step: 527
# working on article with id: 565c812c38f0d83cebcef197
# 1
# 2
# work in progress, step: 528
# working on article with id: 565c70e738f0d81f86d4e4ee
# 1
# 2
# work in progress, step: 529
# working on article with id: 565c5f9138f0d81f86d4e4ad
# 1
# 2
# work in progress, step: 530
# working on article with id: 565c415038f0d81f86d4e453
# 1
# 2
# work in progress, step: 531
# working on article with id: 565c397138f0d81f86d4e43c
# 1
# 2
# work in progress, step: 532
# working on article with id: 565c360e38f0d81f86d4e433
# 1
# 2
# work in progress, step: 533
# working on article with id: 565c314138f0d81f86d4e42c
# 1
# 2
# work in progress, step: 534
# working on article with id: 565c2ce938f0d81f86d4e41d
# 1
# 2
# work in progress, step: 535
# working on article with id: 565bd8ab38f0d81f86d4e339
# 1
# 2
# work in progress, step: 536
# working on article with id: 565d0d5938f0d83cebcef32f
# 1
# 2
# Check the bad link list, because there are 22 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 537
# working on article with id: 565d020f38f0d83cebcef318
# 1
# 2
# Check the bad link list, because there are 23 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 538
# working on article with id: 565bac2d38f0d81f86d4e2ba
# 1
# 2
# work in progress, step: 539
# working on article with id: 565ba76238f0d81f86d4e2b0
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 540
# working on article with id: 565ba0cb38f0d81f86d4e2a5
# 1
# 2
# work in progress, step: 541
# working on article with id: 565b9f1338f0d81f86d4e2a2
# 1
# 2
# work in progress, step: 542
# working on article with id: 565b986b38f0d81f86d4e295
# 1
# 2
# work in progress, step: 543
# working on article with id: 565b95ec38f0d81f86d4e28e
# 1
# 2
# work in progress, step: 544
# working on article with id: 565b896c38f0d81f86d4e276
# 1
# 2
# work in progress, step: 545
# working on article with id: 565b840c38f0d81f86d4e26e
# 1
# 2
# work in progress, step: 546
# working on article with id: 565b7f2338f0d81f86d4e267
# 1
# 2
# work in progress, step: 547
# working on article with id: 565b7e4a38f0d81f86d4e265
# 1
# 2
# work in progress, step: 548
# working on article with id: 565b67ae38f0d81f86d4e231
# 1
# 2
# work in progress, step: 549
# working on article with id: 565b4b5a38f0d81f86d4e20a
# 1
# 2
# work in progress, step: 550
# working on article with id: 565b490e38f0d81f86d4e203
# 1
# 2
# work in progress, step: 551
# working on article with id: 565ae41138f0d80bc460a1eb
# 1
# 2
# work in progress, step: 552
# working on article with id: 565a89e038f0d80bc460a180
# 1
# 2
# work in progress, step: 553
# working on article with id: 565a89dc38f0d80bc460a17a
# 1
# 2
# work in progress, step: 554
# working on article with id: 565a89db38f0d80bc460a179
# 1
# 2
# work in progress, step: 555
# working on article with id: 565a89db38f0d80bc460a178
# 1
# 2
# work in progress, step: 556
# working on article with id: 565a89dd38f0d80bc460a17b
# 1
# 2
# work in progress, step: 557
# working on article with id: 565a89da38f0d80bc460a176
# 1
# 2
# work in progress, step: 558
# working on article with id: 565a89db38f0d80bc460a177
# 1
# 2
# work in progress, step: 559
# working on article with id: 565a89dd38f0d80bc460a17c
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 560
# working on article with id: 565a89e038f0d80bc460a17f
# 1
# 2
# work in progress, step: 561
# working on article with id: 565a89e338f0d80bc460a182
# 1
# 2
# work in progress, step: 562
# working on article with id: 565a89df38f0d80bc460a17d
# 1
# 2
# work in progress, step: 563
# working on article with id: 565a89df38f0d80bc460a17e
# 1
# 2
# work in progress, step: 564
# working on article with id: 565a89e138f0d80bc460a181
# 1
# 2
# work in progress, step: 565
# working on article with id: 565a7e0238f0d80bc460a164
# 1
# 2
# work in progress, step: 566
# working on article with id: 565a3d9738f0d80bc460a10d
# 1
# 2
# work in progress, step: 567
# working on article with id: 565a360538f0d80bc460a102
# 1
# 2
# work in progress, step: 568
# working on article with id: 565a357a38f0d80bc460a100
# 1
# 2
# work in progress, step: 569
# working on article with id: 565a326f38f0d80bc460a0fd
# 1
# 2
# work in progress, step: 570
# working on article with id: 5659ddeb38f0d80bc460a079
# 1
# 2
# work in progress, step: 571
# working on article with id: 565919cd38f0d86d6ede46ab
# 1
# 2
# work in progress, step: 572
# working on article with id: 565912b538f0d86d6ede469c
# 1
# 2
# work in progress, step: 573
# working on article with id: 5658f99138f0d86d6ede466e
# 1
# 2
# work in progress, step: 574
# working on article with id: 5658f7af38f0d86d6ede466a
# 1
# 2
# work in progress, step: 575
# working on article with id: 5658c6ff38f0d86d6ede460f
# 1
# 2
# work in progress, step: 576
# working on article with id: 5658bfc938f0d86d6ede45f8
# 1
# 2
# work in progress, step: 577
# working on article with id: 5658b8f438f0d86d6ede45ee
# 1
# 2
# work in progress, step: 578
# working on article with id: 5658939338f0d86d6ede4585
# 1
# 2
# work in progress, step: 579
# working on article with id: 5658919c38f0d86d6ede4580
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 580
# working on article with id: 5658780438f0d8534437301e
# 1
# 2
# work in progress, step: 581
# working on article with id: 5658722d38f0d8534437300a
# 1
# 2
# work in progress, step: 582
# working on article with id: 56586afe38f0d85344372ff6
# 1
# 2
# work in progress, step: 583
# working on article with id: 565868c738f0d85344372ff0
# 1
# 2
# work in progress, step: 584
# working on article with id: 565829c738f0d85344372f61
# 1
# 2
# work in progress, step: 585
# working on article with id: 56581e6338f0d85344372f33
# 1
# 2
# work in progress, step: 586
# working on article with id: 5658c0db38f0d86d6ede45fc
# 1
# 2
# Check the bad link list, because there are 24 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 587
# working on article with id: 5657c7ce38f0d85344372e97
# 1
# 2
# work in progress, step: 588
# working on article with id: 5657b07f38f0d85344372e76
# 1
# 2
# work in progress, step: 589
# working on article with id: 5657a73938f0d85344372e69
# 1
# 2
# work in progress, step: 590
# working on article with id: 565785c738f0d85344372e3f
# 1
# 2
# work in progress, step: 591
# working on article with id: 56576add38f0d85344372e08
# 1
# 2
# work in progress, step: 592
# working on article with id: 5685edf038f0d85a6c130231
# 1
# 2
# work in progress, step: 593
# working on article with id: 5685b7ce38f0d85a6c1301f5
# 1
# 2
# work in progress, step: 594
# working on article with id: 5685acca38f0d85a6c1301d9
# 1
# 2
# work in progress, step: 595
# working on article with id: 568585ae38f0d85a6c13016f
# 1
# 2
# work in progress, step: 596
# working on article with id: 56856a2338f0d85a6c13012d
# 1
# 2
# work in progress, step: 597
# working on article with id: 568567fd38f0d85a6c130123
# 1
# 2
# work in progress, step: 598
# working on article with id: 568563a738f0d85a6c130118
# 1
# 2
# work in progress, step: 599
# working on article with id: 5685465f38f0d83cec271056
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 600
# working on article with id: 56852fbd38f0d83cec27102e
# 1
# 2
# work in progress, step: 601
# working on article with id: 5684d67938f0d83cec270f6a
# 1
# 2
# work in progress, step: 602
# working on article with id: 5684e7a238f0d83cec270f91
# 1
# 2
# work in progress, step: 603
# working on article with id: 5685ac4938f0d85a6c1301d0
# 1
# 2
# Check the bad link list, because there are 25 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 604
# working on article with id: 568593ad38f0d85a6c13018e
# 1
# 2
# Check the bad link list, because there are 26 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 605
# working on article with id: 5685a51b38f0d85a6c1301bd
# 1
# 2
# Check the bad link list, because there are 27 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 606
# working on article with id: 56849b1238f0d83cec270f06
# 1
# 2
# work in progress, step: 607
# working on article with id: 56848ced38f0d83cec270eec
# 1
# 2
# work in progress, step: 608
# working on article with id: 56848bac38f0d83cec270ee8
# 1
# 2
# work in progress, step: 609
# working on article with id: 56848aaf38f0d83cec270ee5
# 1
# 2
# work in progress, step: 610
# working on article with id: 56847b4538f0d83cec270eca
# 1
# 2
# work in progress, step: 611
# working on article with id: 56847aa538f0d83cec270ec8
# 1
# 2
# work in progress, step: 612
# working on article with id: 5684732738f0d83cec270ebc
# 1
# 2
# work in progress, step: 613
# working on article with id: 568472b338f0d83cec270eba
# 1
# 2
# work in progress, step: 614
# working on article with id: 5684649038f0d83cec270ea3
# 1
# 2
# work in progress, step: 615
# working on article with id: 56845f3738f0d83cec270e95
# 1
# 2
# work in progress, step: 616
# working on article with id: 56845d1238f0d83cec270e91
# 1
# 2
# work in progress, step: 617
# working on article with id: 5684571238f0d83cec270e83
# 1
# 2
# work in progress, step: 618
# working on article with id: 5684503838f0d83cec270e77
# 1
# 2
# work in progress, step: 619
# working on article with id: 5684470538f0d83cec270e5c
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 620
# working on article with id: 568443cc38f0d83cec270e58
# 1
# 2
# work in progress, step: 621
# working on article with id: 568428a638f0d83cec270e1a
# 1
# 2
# work in progress, step: 622
# working on article with id: 5684223838f0d83cec270e07
# 1
# 2
# work in progress, step: 623
# working on article with id: 5684202b38f0d83cec270e01
# 1
# 2
# work in progress, step: 624
# working on article with id: 5684182438f0d83cec270df3
# 1
# 2
# work in progress, step: 625
# working on article with id: 5684145338f0d83cec270de5
# 1
# 2
# work in progress, step: 626
# working on article with id: 5684100338f0d83cec270dd8
# 1
# 2
# work in progress, step: 627
# working on article with id: 56840e9738f0d83cec270dd5
# 1
# 2
# work in progress, step: 628
# working on article with id: 5684005738f0d81f38b9da33
# 1
# 2
# work in progress, step: 629
# working on article with id: 5683fd3338f0d81f38b9da2c
# 1
# 2
# work in progress, step: 630
# working on article with id: 5683f50f38f0d81f38b9da17
# 1
# 2
# work in progress, step: 631
# working on article with id: 5683effc38f0d81f38b9da05
# 1
# 2
# work in progress, step: 632
# working on article with id: 5683ef3e38f0d81f38b9da02
# 1
# 2
# work in progress, step: 633
# working on article with id: 5683e55238f0d81f38b9d9f3
# 1
# 2
# work in progress, step: 634
# working on article with id: 5683d88e38f0d81f38b9d9d7
# 1
# 2
# work in progress, step: 635
# working on article with id: 5683d45d38f0d81f38b9d9c8
# 1
# 2
# work in progress, step: 636
# working on article with id: 5683c7bc38f0d81f38b9d9a9
# 1
# 2
# work in progress, step: 637
# working on article with id: 5683c09738f0d81f38b9d997
# 1
# 2
# work in progress, step: 638
# working on article with id: 5683ab2a38f0d81f38b9d95d
# 1
# 2
# work in progress, step: 639
# working on article with id: 56840a3438f0d81f38b9da46
# 1
# 2
# Check the bad link list, because there are 28 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 640
# working on article with id: 56834e1a38f0d81f38b9d8a1
# 1
# 2
# work in progress, step: 641
# working on article with id: 5683492d38f0d81f38b9d899
# 1
# 2
# work in progress, step: 642
# working on article with id: 5682f3db38f0d81f38b9d7fc
# 1
# 2
# work in progress, step: 643
# working on article with id: 5683313e38f0d81f38b9d876
# 1
# 2
# work in progress, step: 644
# working on article with id: 56831ca338f0d81f38b9d853
# 1
# 2
# work in progress, step: 645
# working on article with id: 5683175e38f0d81f38b9d849
# 1
# 2
# work in progress, step: 646
# working on article with id: 56830f8f38f0d81f38b9d836
# 1
# 2
# work in progress, step: 647
# working on article with id: 56830ef438f0d81f38b9d835
# 1
# 2
# work in progress, step: 648
# working on article with id: 56830df138f0d81f38b9d832
# 1
# 2
# work in progress, step: 649
# working on article with id: 56830ad038f0d81f38b9d82c
# 1
# 2
# work in progress, step: 650
# working on article with id: 5683095e38f0d81f38b9d82a
# 1
# 2
# work in progress, step: 651
# working on article with id: 5683024638f0d81f38b9d81e
# 1
# 2
# work in progress, step: 652
# working on article with id: 5682e19338f0d81f38b9d7ce
# 1
# 2
# work in progress, step: 653
# working on article with id: 5682dfb938f0d81f38b9d7c8
# 1
# 2
# work in progress, step: 654
# working on article with id: 5682dd7e38f0d81f38b9d7c6
# 1
# 2
# work in progress, step: 655
# working on article with id: 5682d8ae38f0d81f38b9d7bf
# 1
# 2
# work in progress, step: 656
# working on article with id: 5682d83b38f0d81f38b9d7be
# 1
# 2
# work in progress, step: 657
# working on article with id: 5682d69438f0d81f38b9d7bb
# 1
# 2
# work in progress, step: 658
# working on article with id: 5682c85938f0d81f38b9d79f
# 1
# 2
# work in progress, step: 659
# working on article with id: 5682c15b38f0d81f38b9d792
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 660
# working on article with id: 5682be4f38f0d81f38b9d786
# 1
# 2
# work in progress, step: 661
# working on article with id: 5682bcbb38f0d81f38b9d781
# 1
# 2
# work in progress, step: 662
# working on article with id: 5682b98b38f0d80161f69480
# 1
# 2
# work in progress, step: 663
# working on article with id: 5682b71a38f0d80161f6947d
# 1
# 2
# work in progress, step: 664
# working on article with id: 5682b0b138f0d80161f69468
# 1
# 2
# work in progress, step: 665
# working on article with id: 5682a9af38f0d80161f6945a
# 1
# 2
# work in progress, step: 666
# working on article with id: 5682a19b38f0d80161f69446
# 1
# 2
# work in progress, step: 667
# working on article with id: 56829e8d38f0d80161f6943f
# 1
# 2
# work in progress, step: 668
# working on article with id: 56829c1f38f0d80161f6943a
# 1
# 2
# work in progress, step: 669
# working on article with id: 5682761f38f0d80161f693ea
# 1
# 2
# work in progress, step: 670
# working on article with id: 56826f5538f0d80161f693db
# 1
# 2
# work in progress, step: 671
# working on article with id: 56826ef638f0d80161f693da
# 1
# 2
# work in progress, step: 672
# working on article with id: 5682684f38f0d80161f693c9
# 1
# 2
# work in progress, step: 673
# working on article with id: 568259bc38f0d80161f693b3
# 1
# 2
# work in progress, step: 674
# working on article with id: 568244ae38f0d80161f69385
# 1
# 2
# work in progress, step: 675
# working on article with id: 56830fa238f0d81f38b9d837
# 1
# 2
# Check the bad link list, because there are 29 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 676
# working on article with id: 568244a738f0d80161f69382
# 1
# 2
# saving what I have in final dic
# adding some missing stuff to dictionary
# there are some links that have not been turned into text see saved badLinkList for current year
# List was saved under name badLinkList2015.pickle
# stopped the text download for year 2015
# the raw text dictionary with name: nytRawText2015.pickle.pickle HAS BEEN found on local drive. SOMETHING is wrong!!!!

# %%
## extracting who is info

# %%
# Out:
# {'name': 'WHOISGUARD PROTECTED', 'organization': 'WHOISGUARD, INC.', 'city': 'PANAMA', 'state': 'PANAMA', 'postalcode': '00000', 'country': 'PA', 'phone': '+507.8365503', 'fax': '+51.17057182', 'email': '3F00CCA35C3B4219A5725395AF9F746A.PROTECT@WHOISGUARD.COM', 'street': 'P.O. BOX 0823-03411'}

# %%
details.keys()
# Out:
# dict_keys(['id', 'status', 'creation_date', 'expiration_date', 'updated_date', 'registrar', 'whois_server', 'nameservers', 'emails', 'contacts', 'raw'])

# %%
details['creation_date'][0]
# Out:
# datetime.datetime(2013, 12, 26, 17, 39)

# %%
dataBigger.getDataNytimes(2014, 2015)
# Out:
# START querying the year: 2014
# TOTAL number of queries used: 0
# dealing with month nr.: 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=1&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=3&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 7
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 8
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 9
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 10
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 11
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 12
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 13
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 14
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 15
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 16
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 17
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 18
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 19
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 20
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 21
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 22
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 23
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 24
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 25
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 26
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 27
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 28
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 29
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 30
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 31
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 32
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 33
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 34
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 35
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 36
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 37
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 38
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 39
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 40
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 41
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 42
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 43
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 44
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 45
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 46
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 47
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 48
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 49
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 50
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 51
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 52
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 53
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 54
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 55
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 56
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 57
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 58
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 59
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 60
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 61
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 62
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 63
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 64
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 65
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 66
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 67
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 68
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 69
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 70
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 71
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 72
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 73
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 74
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 75
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 76
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 77
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 78
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 79
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 80
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 81
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 82
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 83
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 84
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 85
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 86
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 87
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 88
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 89
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 90
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 91
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 92
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 93
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 94
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 95
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 96
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 97
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 98
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 99
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 100
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140101&end_date=20140131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# File was not found, I will create empty dictionary with name nytSnippets2014
# finished and saved month nr.: 1for year :2014
# dealing with month nr.: 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=1&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=3&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=5&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 7
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 8
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 9
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 10
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 11
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 12
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 13
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 14
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 15
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 16
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 17
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 18
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 19
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 20
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 21
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 22
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 23
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 24
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 25
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 26
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 27
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 28
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 29
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 30
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 31
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 32
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 33
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 34
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 35
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 36
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 37
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 38
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 39
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 40
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 41
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 42
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 43
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 44
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 45
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20140201&end_date=20140228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# ...
# 1
# 2
# Check the bad link list, because there are 13 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 644
# working on article with id: 54297f0b38f0d843596a33ec
# 1
# 2
# work in progress, step: 645
# working on article with id: 54543fa438f0d839202e9d20
# 1
# 2
# work in progress, step: 646
# working on article with id: 5454167f38f0d839202e9968
# 1
# 2
# work in progress, step: 647
# working on article with id: 54540d7b38f0d839202e98ab
# 1
# 2
# work in progress, step: 648
# working on article with id: 5453fe3c38f0d839202e9731
# 1
# 2
# work in progress, step: 649
# working on article with id: 5453eb2f38f0d839202e9556
# 1
# 2
# work in progress, step: 650
# working on article with id: 5453e2f938f0d839202e948b
# 1
# 2
# work in progress, step: 651
# working on article with id: 5453e03f38f0d839202e944d
# 1
# 2
# work in progress, step: 652
# working on article with id: 5453d61038f0d839202e9371
# 1
# 2
# work in progress, step: 653
# working on article with id: 5453ca7238f0d839202e9263
# 1
# 2
# work in progress, step: 654
# working on article with id: 5453bc8638f0d839202e9105
# 1
# 2
# work in progress, step: 655
# working on article with id: 5453b95b38f0d839202e90b1
# 1
# 2
# work in progress, step: 656
# working on article with id: 5453b95d38f0d839202e90b3
# 1
# 2
# work in progress, step: 657
# working on article with id: 5453b24e38f0d839202e9008
# 1
# 2
# work in progress, step: 658
# working on article with id: 54536f1138f0d81b603edfac
# 1
# 2
# Check the bad link list, because there are 14 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 659
# working on article with id: 54539c0b38f0d81b603ee390
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 660
# working on article with id: 54539ac338f0d81b603ee37a
# 1
# 2
# work in progress, step: 661
# working on article with id: 5453984b38f0d81b603ee346
# 1
# 2
# work in progress, step: 662
# working on article with id: 54537e8338f0d81b603ee106
# 1
# 2
# work in progress, step: 663
# working on article with id: 545374e338f0d81b603ee034
# 1
# 2
# work in progress, step: 664
# working on article with id: 54536d2d38f0d81b603edf7d
# 1
# 2
# work in progress, step: 665
# working on article with id: 54536b6c38f0d81b603edf55
# 1
# 2
# work in progress, step: 666
# working on article with id: 54534f4a38f0d81b603edcdf
# 1
# 2
# work in progress, step: 667
# working on article with id: 5453415338f0d81b603edb9b
# 1
# 2
# work in progress, step: 668
# working on article with id: 5453fa7938f0d839202e96d9
# 1
# 2
# work in progress, step: 669
# working on article with id: 5452ee2938f0d81b603ed435
# 1
# 2
# work in progress, step: 670
# working on article with id: 5452e93938f0d81b603ed3ca
# 1
# 2
# work in progress, step: 671
# working on article with id: 5452e30238f0d81b603ed344
# 1
# 2
# work in progress, step: 672
# working on article with id: 5452e2a638f0d81b603ed33e
# 1
# 2
# work in progress, step: 673
# working on article with id: 5452dd5238f0d81b603ed2bd
# 1
# 2
# work in progress, step: 674
# working on article with id: 5452da5a38f0d81b603ed279
# 1
# 2
# work in progress, step: 675
# working on article with id: 5452d90738f0d81b603ed258
# 1
# 2
# work in progress, step: 676
# working on article with id: 5452d7e838f0d81b603ed23d
# 1
# 2
# work in progress, step: 677
# working on article with id: 5452d75938f0d81b603ed230
# 1
# 2
# work in progress, step: 678
# working on article with id: 5452cd5a38f0d81b603ed142
# 1
# 2
# work in progress, step: 679
# working on article with id: 5452cab638f0d81b603ed109
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 680
# working on article with id: 5452c83438f0d81b603ed0d2
# 1
# 2
# work in progress, step: 681
# working on article with id: 5452c72338f0d81b603ed0b4
# 1
# 2
# work in progress, step: 682
# working on article with id: 5452bd8638f0d81b603ecfcd
# 1
# 2
# work in progress, step: 683
# working on article with id: 5452ba4c38f0d81b603ecf7c
# 1
# 2
# work in progress, step: 684
# working on article with id: 5452b6b438f0d81b603ecf24
# 1
# 2
# work in progress, step: 685
# working on article with id: 5452a79938f0d81b603ecd92
# 1
# 2
# work in progress, step: 686
# working on article with id: 5452a29c38f0d81b603ecd1f
# 1
# 2
# Check the bad link list, because there are 15 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 687
# working on article with id: 545298fd38f0d81b603ecc35
# 1
# 2
# work in progress, step: 688
# working on article with id: 5452960c38f0d81b603ecbf4
# 1
# 2
# work in progress, step: 689
# working on article with id: 5452933638f0d81b603ecbb1
# 1
# 2
# work in progress, step: 690
# working on article with id: 5452906738f0d81b603ecb63
# 1
# 2
# work in progress, step: 691
# working on article with id: 54527ff538f0d81b603ec9db
# 1
# 2
# work in progress, step: 692
# working on article with id: 5452735b38f0d81b603ec8af
# 1
# 2
# work in progress, step: 693
# working on article with id: 545270e738f0d81b603ec871
# 1
# 2
# work in progress, step: 694
# working on article with id: 54526b9e38f0d81b603ec7eb
# 1
# 2
# work in progress, step: 695
# working on article with id: 54526a7038f0d81b603ec7ca
# 1
# 2
# work in progress, step: 696
# working on article with id: 5452629538f0d81b603ec70d
# 1
# 2
# work in progress, step: 697
# working on article with id: 5452530338f0d87c5c3678c4
# 1
# 2
# work in progress, step: 698
# working on article with id: 545246d738f0d87c5c367898
# 1
# 2
# work in progress, step: 699
# working on article with id: 5452452238f0d87c5c367889
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 700
# working on article with id: 545236a338f0d87c5c36785d
# 1
# 2
# work in progress, step: 701
# working on article with id: 5452337138f0d87c5c367855
# 1
# 2
# work in progress, step: 702
# working on article with id: 5452300038f0d87c5c367847
# 1
# 2
# work in progress, step: 703
# working on article with id: 54522fd738f0d87c5c367846
# 1
# 2
# work in progress, step: 704
# working on article with id: 5452245c38f0d87c5c367829
# 1
# 2
# work in progress, step: 705
# working on article with id: 5452245d38f0d87c5c36782a
# 1
# 2
# work in progress, step: 706
# working on article with id: 54521c6138f0d87c5c36780c
# 1
# 2
# work in progress, step: 707
# working on article with id: 54521a8838f0d87c5c367809
# 1
# 2
# work in progress, step: 708
# working on article with id: 5452033738f0d87c5c3677cd
# 1
# 2
# work in progress, step: 709
# working on article with id: 5451fe2638f0d87c5c3677be
# 1
# 2
# work in progress, step: 710
# working on article with id: 5451e1ba38f0d87c5c36776e
# 1
# 2
# work in progress, step: 711
# working on article with id: 5451e12838f0d87c5c36776c
# 1
# 2
# work in progress, step: 712
# working on article with id: 5452c29b38f0d81b603ed04f
# 1
# 2
# Check the bad link list, because there are 16 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 713
# working on article with id: 5451b81938f0d87c5c367713
# 1
# 2
# work in progress, step: 714
# working on article with id: 5452607c38f0d87c5c367985
# 1
# 2
# work in progress, step: 715
# working on article with id: 5451ab9a38f0d87c5c367709
# 1
# 2
# work in progress, step: 716
# working on article with id: 54519f3438f0d87c5c3676b6
# 1
# 2
# work in progress, step: 717
# working on article with id: 54519cad38f0d87c5c3676ad
# 1
# 2
# work in progress, step: 718
# working on article with id: 54519c3038f0d87c5c3676ac
# 1
# 2
# work in progress, step: 719
# working on article with id: 54518dc338f0d87c5c367688
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 720
# working on article with id: 5451843338f0d87c5c36766e
# 1
# 2
# work in progress, step: 721
# working on article with id: 5451833e38f0d87c5c367667
# 1
# 2
# work in progress, step: 722
# working on article with id: 54517d8438f0d87c5c36764e
# 1
# 2
# work in progress, step: 723
# working on article with id: 54517a2f38f0d87c5c367645
# 1
# 2
# work in progress, step: 724
# working on article with id: 545175ca38f0d87c5c36763b
# 1
# 2
# work in progress, step: 725
# working on article with id: 5451721438f0d87c5c367633
# 1
# 2
# work in progress, step: 726
# working on article with id: 54516f2838f0d87c5c36762a
# 1
# 2
# work in progress, step: 727
# working on article with id: 54516b5838f0d87c5c367619
# 1
# 2
# work in progress, step: 728
# working on article with id: 5451557338f0d87c5c3675ba
# 1
# 2
# work in progress, step: 729
# working on article with id: 5451516738f0d87c5c3675ad
# 1
# 2
# work in progress, step: 730
# working on article with id: 54514b6038f0d87c5c367599
# 1
# 2
# work in progress, step: 731
# working on article with id: 545149dd38f0d87c5c36758e
# 1
# 2
# work in progress, step: 732
# working on article with id: 54514a6538f0d87c5c367592
# 1
# 2
# work in progress, step: 733
# working on article with id: 545146a038f0d87c5c367586
# 1
# 2
# work in progress, step: 734
# working on article with id: 5451426e38f0d87c5c367573
# 1
# 2
# work in progress, step: 735
# working on article with id: 547ba21438f0d813efccb461
# 1
# 2
# work in progress, step: 736
# working on article with id: 547b075b38f0d803f445c620
# 1
# 2
# work in progress, step: 737
# working on article with id: 547aa7e038f0d803f445be3a
# 1
# 2
# work in progress, step: 738
# working on article with id: 547aa7e038f0d803f445be3b
# 1
# 2
# work in progress, step: 739
# working on article with id: 547aa7f538f0d803f445be43
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 740
# working on article with id: 547aa7e038f0d803f445be38
# 1
# 2
# work in progress, step: 741
# working on article with id: 547aa7e038f0d803f445be39
# 1
# 2
# work in progress, step: 742
# working on article with id: 547aa7e138f0d803f445be3f
# 1
# 2
# work in progress, step: 743
# working on article with id: 547aa7df38f0d803f445be35
# 1
# 2
# work in progress, step: 744
# working on article with id: 547aa7e138f0d803f445be3e
# 1
# 2
# work in progress, step: 745
# working on article with id: 547aa7df38f0d803f445be36
# 1
# 2
# work in progress, step: 746
# working on article with id: 547aa7e138f0d803f445be3d
# 1
# 2
# work in progress, step: 747
# working on article with id: 547aa7e338f0d803f445be41
# 1
# 2
# work in progress, step: 748
# working on article with id: 547aa7e138f0d803f445be3c
# 1
# 2
# work in progress, step: 749
# working on article with id: 547aa7e338f0d803f445be40
# 1
# 2
# work in progress, step: 750
# working on article with id: 547a61c638f0d803f445b84d
# 1
# 2
# work in progress, step: 751
# working on article with id: 547a507238f0d803f445b6da
# 1
# 2
# work in progress, step: 752
# working on article with id: 547a4f3438f0d803f445b6bd
# 1
# 2
# work in progress, step: 753
# working on article with id: 547a2c4638f0d803f445b3b9
# 1
# 2
# work in progress, step: 754
# working on article with id: 54c5ad6138f0d86e74551527
# 1
# 2
# Check the bad link list, because there are 17 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 755
# working on article with id: 5479382638f0d86bf592f140
# 1
# 2
# work in progress, step: 756
# working on article with id: 547921e738f0d86bf592ef57
# 1
# 2
# work in progress, step: 757
# working on article with id: 54791e5338f0d86bf592ef0d
# 1
# 2
# work in progress, step: 758
# working on article with id: 54790a5338f0d86bf592ed8d
# 1
# 2
# work in progress, step: 759
# working on article with id: 547907e638f0d86bf592ed58
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 760
# working on article with id: 5478ede438f0d86bf592eafe
# 1
# 2
# work in progress, step: 761
# working on article with id: 5478dc1338f0d86bf592e961
# 1
# 2
# work in progress, step: 762
# working on article with id: 5478cee638f0d86bf592e83c
# 1
# 2
# work in progress, step: 763
# working on article with id: 5478c8b538f0d86bf592e7a9
# 1
# 2
# work in progress, step: 764
# working on article with id: 5478c60238f0d86bf592e771
# 1
# 2
# work in progress, step: 765
# working on article with id: 5478bcb538f0d86bf592e699
# 1
# 2
# work in progress, step: 766
# working on article with id: 5478b73038f0d86bf592e613
# 1
# 2
# work in progress, step: 767
# working on article with id: 5478a52438f0d854b20b369b
# 1
# 2
# work in progress, step: 768
# working on article with id: 5478a04438f0d854b20b362a
# 1
# 2
# work in progress, step: 769
# working on article with id: 547892b538f0d854b20b3502
# 1
# 2
# work in progress, step: 770
# working on article with id: 5478837738f0d854b20b339a
# 1
# 2
# work in progress, step: 771
# working on article with id: 5478780038f0d854b20b328b
# 1
# 2
# work in progress, step: 772
# working on article with id: 5478517438f0d854b20b2f14
# 1
# 2
# work in progress, step: 773
# working on article with id: 5478489c38f0d854b20b2e43
# 1
# 2
# work in progress, step: 774
# working on article with id: 5478ea0c38f0d86bf592ea9f
# 1
# 2
# work in progress, step: 775
# working on article with id: 5477fc7438f0d854b20b27bf
# 1
# 2
# work in progress, step: 776
# working on article with id: 5477e5e638f0d854b20b25b0
# 1
# 2
# work in progress, step: 777
# working on article with id: 5477d2c338f0d854b20b2400
# 1
# 2
# work in progress, step: 778
# working on article with id: 5477d15438f0d854b20b23e2
# 1
# 2
# work in progress, step: 779
# working on article with id: 5477cc3e38f0d854b20b237f
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 780
# working on article with id: 5477c68b38f0d854b20b22f7
# 1
# 2
# work in progress, step: 781
# working on article with id: 5477b14438f0d854b20b211f
# 1
# 2
# work in progress, step: 782
# working on article with id: 54779e0c38f0d854b20b1f75
# 1
# 2
# work in progress, step: 783
# working on article with id: 5477966838f0d854b20b1ece
# 1
# 2
# work in progress, step: 784
# working on article with id: 5477790938f0d854b20b1c30
# 1
# 2
# work in progress, step: 785
# working on article with id: 54776bba38f0d854b20b1afa
# 1
# 2
# work in progress, step: 786
# working on article with id: 5477661138f0d854b20b1a78
# 1
# 2
# work in progress, step: 787
# working on article with id: 547745b638f0d83924902efc
# 1
# 2
# work in progress, step: 788
# working on article with id: 54a4b92538f0d83a07dc530c
# 1
# 2
# work in progress, step: 789
# working on article with id: 54a481f238f0d83a07dc4666
# 1
# 2
# work in progress, step: 790
# working on article with id: 54a46be538f0d83a07dc4158
# 1
# 2
# work in progress, step: 791
# working on article with id: 54a44fc638f0d83a07dc3ae7
# 1
# 2
# work in progress, step: 792
# working on article with id: 54a42d7b38f0d83a07dc315e
# 1
# 2
# work in progress, step: 793
# working on article with id: 54a4196b38f0d80267d2a5e5
# 1
# 2
# work in progress, step: 794
# working on article with id: 54a414be38f0d80267d2a50c
# 1
# 2
# work in progress, step: 795
# working on article with id: 54a409b738f0d80267d2a3bf
# 1
# 2
# work in progress, step: 796
# working on article with id: 54a401c638f0d80267d2a2e0
# 1
# 2
# work in progress, step: 797
# working on article with id: 54a3f33738f0d80267d2a131
# 1
# 2
# work in progress, step: 798
# working on article with id: 54a3d9e838f0d80267d29e54
# 1
# 2
# work in progress, step: 799
# working on article with id: 54a3832d38f0d80267d29426
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 800
# working on article with id: 54a4a6a138f0d83a07dc4eca
# 1
# 2
# Check the bad link list, because there are 18 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 801
# working on article with id: 54a42aae38f0d80267d2abaf
# 1
# 2
# Check the bad link list, because there are 19 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 802
# working on article with id: 54a371ce38f0d80267d29319
# 1
# 2
# work in progress, step: 803
# working on article with id: 54a36f8938f0d80267d29313
# 1
# 2
# work in progress, step: 804
# working on article with id: 54a36bd538f0d80267d2930b
# 1
# 2
# work in progress, step: 805
# working on article with id: 54a3671538f0d80267d29304
# 1
# 2
# work in progress, step: 806
# working on article with id: 54a3666c38f0d80267d29302
# 1
# 2
# work in progress, step: 807
# working on article with id: 54a364eb38f0d80267d292fe
# 1
# 2
# saving what I have in final dic
# adding some missing stuff to dictionary
# there are some links that have not been turned into text see saved badLinkList for current year
# List was saved under name badLinkList2014.pickle
# stopped the text download for year 2014
# the raw text dictionary with name: nytRawText2014.pickle.pickle HAS BEEN found on local drive. SOMETHING is wrong!!!!

# %%
dataBigger.getDataNytimes(2013, 2014)
# Out:
# START querying the year: 2013
# TOTAL number of queries used: 91
# dealing with month nr.: 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=1&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 7
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 8
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 9
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 10
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 11
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 12
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 13
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 14
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 15
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 16
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 17
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 18
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 19
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 20
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 21
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 22
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 23
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 24
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 25
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 26
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 27
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 28
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 29
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 30
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 31
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 32
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 33
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 34
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 35
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 36
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 37
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 38
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 39
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 40
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 41
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 42
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 43
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 44
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 45
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 46
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 47
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 48
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 49
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 50
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 51
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 52
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 53
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 54
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 55
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 56
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 57
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 58
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 59
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 60
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 61
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 62
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 63
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 64
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 65
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 66
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 67
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 68
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 69
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 70
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 71
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 72
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 73
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 74
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 75
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 76
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 77
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 78
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 79
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 80
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 81
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 82
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 83
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 84
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 85
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 86
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 87
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 88
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 89
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 90
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 91
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 92
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 93
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 94
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 95
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 96
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 97
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 98
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 99
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 100
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130101&end_date=20130131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# File was not found, I will create empty dictionary with name nytSnippets2013
# finished and saved month nr.: 1for year :2013
# dealing with month nr.: 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 7
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 8
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=1&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=3&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=5&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :7
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=8&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :8
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130201&end_date=20130228&sort=newest&page=9&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :9
# finished and saved month nr.: 2for year :2013
# dealing with month nr.: 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130301&end_date=20130331&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130301&end_date=20130331&sort=newest&page=1&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130301&end_date=20130331&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130301&end_date=20130331&sort=newest&page=3&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130301&end_date=20130331&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130301&end_date=20130331&sort=newest&page=5&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130301&end_date=20130331&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130301&end_date=20130331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :7
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130301&end_date=20130331&sort=newest&page=8&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :8
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130301&end_date=20130331&sort=newest&page=9&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :9
# finished and saved month nr.: 3for year :2013
# dealing with month nr.: 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130401&end_date=20130430&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130401&end_date=20130430&sort=newest&page=1&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130401&end_date=20130430&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130401&end_date=20130430&sort=newest&page=3&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130401&end_date=20130430&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130401&end_date=20130430&sort=newest&page=5&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130401&end_date=20130430&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130401&end_date=20130430&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :7
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130401&end_date=20130430&sort=newest&page=8&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :8
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130401&end_date=20130430&sort=newest&page=9&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :9
# finished and saved month nr.: 4for year :2013
# dealing with month nr.: 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130501&end_date=20130531&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130501&end_date=20130531&sort=newest&page=1&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130501&end_date=20130531&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130501&end_date=20130531&sort=newest&page=3&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130501&end_date=20130531&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130501&end_date=20130531&sort=newest&page=5&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130501&end_date=20130531&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130501&end_date=20130531&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :7
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130501&end_date=20130531&sort=newest&page=8&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130501&end_date=20130531&sort=newest&page=8&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130501&end_date=20130531&sort=newest&page=8&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130501&end_date=20130531&sort=newest&page=8&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130501&end_date=20130531&sort=newest&page=8&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130501&end_date=20130531&sort=newest&page=8&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130501&end_date=20130531&sort=newest&page=8&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130501&end_date=20130531&sort=newest&page=8&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 7
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20130501&end_date=20130531&sort=newest&page=8&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 8
# ...
# 1
# 2
# work in progress, step: 602
# working on article with id: 5271711238f0d869cf22d4f2
# 1
# 2
# work in progress, step: 603
# working on article with id: 52716fd538f0d869cf22d4e7
# 1
# 2
# work in progress, step: 604
# working on article with id: 52714b8b38f0d869cf22d427
# 1
# 2
# work in progress, step: 605
# working on article with id: 5271397038f0d869cf22d3d8
# 1
# 2
# work in progress, step: 606
# working on article with id: 5271382338f0d869cf22d3d4
# 1
# 2
# work in progress, step: 607
# working on article with id: 52712fe338f0d869cf22d3ab
# 1
# 2
# work in progress, step: 608
# working on article with id: 52712c4038f0d83b1c1399d5
# 1
# 2
# work in progress, step: 609
# working on article with id: 52712ac038f0d83b1c1399d0
# 1
# 2
# work in progress, step: 610
# working on article with id: 527129d938f0d83b1c1399ce
# 1
# 2
# work in progress, step: 611
# working on article with id: 527113f638f0d83b1c13997f
# 1
# 2
# work in progress, step: 612
# working on article with id: 52710c4738f0d83b1c139962
# 1
# 2
# work in progress, step: 613
# working on article with id: 5270fc6538f0d83b1c139934
# 1
# 2
# work in progress, step: 614
# working on article with id: 5270eebc38f0d83b1c139906
# 1
# 2
# work in progress, step: 615
# working on article with id: 5270e56338f0d83b1c1398ef
# 1
# 2
# work in progress, step: 616
# working on article with id: 527160ea38f0d869cf22d498
# 1
# 2
# Check the bad link list, because there are 71 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 617
# working on article with id: 527086de38f0d83b1c13984b
# 1
# 2
# work in progress, step: 618
# working on article with id: 5283b4f238f0d877254533b0
# 1
# 2
# Check the bad link list, because there are 72 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 619
# working on article with id: 5270d8aa38f0d83b1c1398d9
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 620
# working on article with id: 5270797638f0d83b1c139836
# 1
# 2
# Check the bad link list, because there are 73 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 621
# working on article with id: 5270759638f0d83b1c139811
# 1
# 2
# work in progress, step: 622
# working on article with id: 5270647738f0d83b1c1397e7
# 1
# 2
# work in progress, step: 623
# working on article with id: 527061c338f0d83b1c1397dd
# 1
# 2
# work in progress, step: 624
# working on article with id: 52705a2638f0d83b1c1397c9
# 1
# 2
# work in progress, step: 625
# working on article with id: 527055cd38f0d83b1c1397bd
# 1
# 2
# work in progress, step: 626
# working on article with id: 5270531938f0d83b1c1397b5
# 1
# 2
# work in progress, step: 627
# working on article with id: 52704e7e38f0d83b1c1397a5
# 1
# 2
# work in progress, step: 628
# working on article with id: 52704c7838f0d83b1c1397a2
# 1
# 2
# work in progress, step: 629
# working on article with id: 52704ad138f0d83b1c13979a
# 1
# 2
# work in progress, step: 630
# working on article with id: 5270490738f0d83b1c139797
# 1
# 2
# work in progress, step: 631
# working on article with id: 5270467538f0d83b1c139794
# 1
# 2
# work in progress, step: 632
# working on article with id: 527045ba38f0d83b1c139792
# 1
# 2
# work in progress, step: 633
# working on article with id: 52703aa838f0d83b1c13977d
# 1
# 2
# work in progress, step: 634
# working on article with id: 5270382c38f0d83b1c139775
# 1
# 2
# work in progress, step: 635
# working on article with id: 5270380d38f0d83b1c139774
# 1
# 2
# work in progress, step: 636
# working on article with id: 5270380a38f0d83b1c139773
# 1
# 2
# work in progress, step: 637
# working on article with id: 5270380138f0d83b1c139770
# 1
# 2
# work in progress, step: 638
# working on article with id: 5270380238f0d83b1c139772
# 1
# 2
# work in progress, step: 639
# working on article with id: 5270380138f0d83b1c139771
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 640
# working on article with id: 527037fd38f0d83b1c13976f
# 1
# 2
# work in progress, step: 641
# working on article with id: 527037fd38f0d83b1c13976e
# 1
# 2
# work in progress, step: 642
# working on article with id: 527037f138f0d83b1c13976c
# 1
# 2
# work in progress, step: 643
# working on article with id: 527037f238f0d83b1c13976d
# 1
# 2
# work in progress, step: 644
# working on article with id: 527036dd38f0d83b1c139767
# 1
# 2
# work in progress, step: 645
# working on article with id: 52701f3138f0d83b1c139727
# 1
# 2
# work in progress, step: 646
# working on article with id: 527014a638f0d83b1c1396e8
# 1
# 2
# work in progress, step: 647
# working on article with id: 5270079838f0d83b1c1396af
# 1
# 2
# work in progress, step: 648
# working on article with id: 526ff95438f0d83b1c13967f
# 1
# 2
# work in progress, step: 649
# working on article with id: 526fd7ba38f0d81489d169d9
# 1
# 2
# work in progress, step: 650
# working on article with id: 526fd67a38f0d81489d169d5
# 1
# 2
# work in progress, step: 651
# working on article with id: 526fbd9a38f0d81489d16973
# 1
# 2
# work in progress, step: 652
# working on article with id: 526fa7ab38f0d81489d16939
# 1
# 2
# work in progress, step: 653
# working on article with id: 526f89e938f0d81489d168e5
# 1
# 2
# work in progress, step: 654
# working on article with id: 526f48ca38f0d81489d16872
# 1
# 2
# work in progress, step: 655
# working on article with id: 526f387338f0d81489d16857
# 1
# 2
# work in progress, step: 656
# working on article with id: 526f873538f0d81489d168de
# 1
# 2
# work in progress, step: 657
# working on article with id: 526f251b38f0d81489d16825
# 1
# 2
# work in progress, step: 658
# working on article with id: 526f201f38f0d81489d1681f
# 1
# 2
# work in progress, step: 659
# working on article with id: 526f19cd38f0d81489d16814
# 1
# 2
# Check the bad link list, because there are 74 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 660
# working on article with id: 526f02db38f0d81489d167df
# 1
# 2
# work in progress, step: 661
# working on article with id: 526efda738f0d81489d167d2
# 1
# 2
# work in progress, step: 662
# working on article with id: 526efda738f0d81489d167d1
# 1
# 2
# work in progress, step: 663
# working on article with id: 526efb7338f0d81489d167ca
# 1
# 2
# work in progress, step: 664
# working on article with id: 526ef9f538f0d81489d167c1
# 1
# 2
# work in progress, step: 665
# working on article with id: 526ef98638f0d81489d167c0
# 1
# 2
# work in progress, step: 666
# working on article with id: 526ef19838f0d81489d167ac
# 1
# 2
# Check the bad link list, because there are 75 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 667
# working on article with id: 526eef5038f0d81489d167ab
# 1
# 2
# work in progress, step: 668
# working on article with id: 526ee82e38f0d81489d1679b
# 1
# 2
# work in progress, step: 669
# working on article with id: 526ee3fd38f0d81489d16792
# 1
# 2
# work in progress, step: 670
# working on article with id: 526ed8fe38f0d81489d1676c
# 1
# 2
# work in progress, step: 671
# working on article with id: 526ed04638f0d81489d1674e
# 1
# 2
# Check the bad link list, because there are 76 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 672
# working on article with id: 526ec8dc38f0d81489d1673a
# 1
# 2
# work in progress, step: 673
# working on article with id: 526eb5c138f0d81489d166f5
# 1
# 2
# work in progress, step: 674
# working on article with id: 52c2a3ba38f0d829ddebe074
# 1
# 2
# work in progress, step: 675
# working on article with id: 52c2dc0938f0d829ddebe0ce
# 1
# 2
# work in progress, step: 676
# working on article with id: 52c21e6838f0d829ddebdf7e
# 1
# 2
# work in progress, step: 677
# working on article with id: 52c216f138f0d829ddebdf6f
# 1
# 2
# work in progress, step: 678
# working on article with id: 52c200b038f0d829ddebdf4f
# 1
# 2
# work in progress, step: 679
# working on article with id: 52c1fb6138f0d829ddebdf40
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 680
# working on article with id: 52c1e2b138f0d829ddebdf06
# 1
# 2
# work in progress, step: 681
# working on article with id: 52c1da8b38f0d829ddebdef4
# 1
# 2
# work in progress, step: 682
# working on article with id: 52c1da7238f0d829ddebdef3
# 1
# 2
# work in progress, step: 683
# working on article with id: 52c1d42c38f0d829ddebdee7
# 1
# 2
# work in progress, step: 684
# working on article with id: 52c1d38d38f0d829ddebdee4
# 1
# 2
# work in progress, step: 685
# working on article with id: 52c1cbde38f0d829ddebded8
# 1
# 2
# work in progress, step: 686
# working on article with id: 52c1c6e538f0d829ddebdec9
# 1
# 2
# work in progress, step: 687
# working on article with id: 52c1c55438f0d829ddebdec6
# 1
# 2
# work in progress, step: 688
# working on article with id: 52c1b74538f0d829ddebde94
# 1
# 2
# work in progress, step: 689
# working on article with id: 52c1ac0738f0d829ddebde81
# 1
# 2
# work in progress, step: 690
# working on article with id: 52c1a9f138f0d829ddebde7b
# 1
# 2
# work in progress, step: 691
# working on article with id: 52c1924238f0d82ddfa1632f
# 1
# 2
# work in progress, step: 692
# working on article with id: 52c1782238f0d82ddfa16300
# 1
# 2
# work in progress, step: 693
# working on article with id: 52c1643638f0d82ddfa162e6
# 1
# 2
# work in progress, step: 694
# working on article with id: 52c1cd4938f0d829ddebdedb
# 1
# 2
# work in progress, step: 695
# working on article with id: 52c0f72f38f0d82ddfa1621a
# 1
# 2
# Check the bad link list, because there are 77 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 696
# working on article with id: 52c0eea238f0d82ddfa161da
# 1
# 2
# Check the bad link list, because there are 78 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 697
# working on article with id: 52c0e60338f0d82ddfa161cb
# 1
# 2
# work in progress, step: 698
# working on article with id: 52c0df9438f0d82ddfa161be
# 1
# 2
# work in progress, step: 699
# working on article with id: 52c0d1e838f0d82ddfa1619c
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 700
# working on article with id: 52c0cd8038f0d82ddfa16191
# 1
# 2
# work in progress, step: 701
# working on article with id: 52c0c82a38f0d82ddfa16189
# 1
# 2
# work in progress, step: 702
# working on article with id: 52c0bd0a38f0d82ddfa1616f
# 1
# 2
# work in progress, step: 703
# working on article with id: 52c0a92538f0d82ddfa1615b
# 1
# 2
# work in progress, step: 704
# working on article with id: 52c0a11738f0d82ddfa1614d
# 1
# 2
# work in progress, step: 705
# working on article with id: 52c09e0d38f0d82ddfa16141
# 1
# 2
# work in progress, step: 706
# working on article with id: 52bfafe038f0d83b2b282cd7
# 1
# 2
# work in progress, step: 707
# working on article with id: 52bfafdf38f0d83b2b282cd5
# 1
# 2
# work in progress, step: 708
# working on article with id: 52bfafe238f0d83b2b282cd8
# 1
# 2
# work in progress, step: 709
# working on article with id: 52bfafe938f0d83b2b282cdb
# 1
# 2
# work in progress, step: 710
# working on article with id: 52bfafe938f0d83b2b282cdc
# 1
# 2
# work in progress, step: 711
# working on article with id: 52bfafe938f0d83b2b282cdd
# 1
# 2
# work in progress, step: 712
# working on article with id: 52bfafe538f0d83b2b282cd9
# 1
# 2
# work in progress, step: 713
# working on article with id: 52bfaff838f0d83b2b282cdf
# 1
# 2
# work in progress, step: 714
# working on article with id: 52bfafe838f0d83b2b282cda
# 1
# 2
# work in progress, step: 715
# working on article with id: 52bfafe038f0d83b2b282cd6
# 1
# 2
# work in progress, step: 716
# working on article with id: 52bfafea38f0d83b2b282cde
# 1
# 2
# work in progress, step: 717
# working on article with id: 52bf49ae38f0d83b2b282c6e
# 1
# 2
# Check the bad link list, because there are 79 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 718
# working on article with id: 52bef6ed38f0d8317f2b0761
# 1
# 2
# work in progress, step: 719
# working on article with id: 52be317a38f0d8317f2b0557
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 720
# working on article with id: 52be2caf38f0d8317f2b051e
# 1
# 2
# work in progress, step: 721
# working on article with id: 52be273d38f0d8317f2b04e5
# 1
# 2
# work in progress, step: 722
# working on article with id: 52be262538f0d8317f2b04d6
# 1
# 2
# work in progress, step: 723
# working on article with id: 52be24c038f0d8317f2b04c5
# 1
# 2
# work in progress, step: 724
# working on article with id: 52be191038f0d8317f2b0437
# 1
# 2
# work in progress, step: 725
# working on article with id: 52be039838f0d8317f2b031e
# 1
# 2
# work in progress, step: 726
# working on article with id: 52bdede838f0d8317f2b01e8
# 1
# 2
# work in progress, step: 727
# working on article with id: 52bdecb538f0d8317f2b01d0
# 1
# 2
# work in progress, step: 728
# working on article with id: 52bdec1338f0d8317f2b01c8
# 1
# 2
# work in progress, step: 729
# working on article with id: 52bdd5d438f0d8317f2b0094
# 1
# 2
# work in progress, step: 730
# working on article with id: 52bdd37138f0d8317f2b0073
# 1
# 2
# work in progress, step: 731
# working on article with id: 52bdd1bb38f0d8317f2b005c
# 1
# 2
# work in progress, step: 732
# working on article with id: 52bdd1c638f0d8317f2b005d
# 1
# 2
# Check the bad link list, because there are 80 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 733
# working on article with id: 52bdc1e638f0d8317f2aff8e
# 1
# 2
# work in progress, step: 734
# working on article with id: 52bdbf6838f0d8317f2aff6c
# 1
# 2
# work in progress, step: 735
# working on article with id: 52bdbdbf38f0d8317f2aff56
# 1
# 2
# work in progress, step: 736
# working on article with id: 52bdb59b38f0d8317f2afedf
# 1
# 2
# work in progress, step: 737
# working on article with id: 52bdaf5e38f0d8377a7ad933
# 1
# 2
# work in progress, step: 738
# working on article with id: 52bf03c438f0d83b2b282c0b
# 1
# 2
# Check the bad link list, because there are 81 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 739
# working on article with id: 52bd127e38f0d8377a7ad679
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 740
# working on article with id: 52bcdcbb38f0d8377a7ad628
# 1
# 2
# work in progress, step: 741
# working on article with id: 52bcd89e38f0d8377a7ad61f
# 1
# 2
# work in progress, step: 742
# working on article with id: 52bcd76038f0d8377a7ad61c
# 1
# 2
# work in progress, step: 743
# working on article with id: 52bcd6db38f0d8377a7ad61b
# 1
# 2
# work in progress, step: 744
# working on article with id: 52bcd41638f0d8377a7ad613
# 1
# 2
# work in progress, step: 745
# working on article with id: 52bcb25438f0d8377a7ad5e6
# 1
# 2
# work in progress, step: 746
# working on article with id: 52bc8fad38f0d8377a7ad597
# 1
# 2
# work in progress, step: 747
# working on article with id: 52bc8ca938f0d8377a7ad592
# 1
# 2
# work in progress, step: 748
# working on article with id: 52bc68f438f0d8377a7ad54d
# 1
# 2
# work in progress, step: 749
# working on article with id: 52bc4dcd38f0d849b07ffab1
# 1
# 2
# work in progress, step: 750
# working on article with id: 52bc372538f0d849b07ffa93
# 1
# 2
# work in progress, step: 751
# working on article with id: 52bc243a38f0d849b07ffa78
# 1
# 2
# work in progress, step: 752
# working on article with id: 52bbae6538f0d849b07ff9fe
# 1
# 2
# work in progress, step: 753
# working on article with id: 52bbade538f0d849b07ff9fd
# 1
# 2
# work in progress, step: 754
# working on article with id: 52bb8d9438f0d849b07ff9be
# 1
# 2
# work in progress, step: 755
# working on article with id: 52bb89ad38f0d849b07ff9b4
# 1
# 2
# work in progress, step: 756
# working on article with id: 52bb81af38f0d849b07ff9aa
# 1
# 2
# work in progress, step: 757
# working on article with id: 52bb7ee238f0d849b07ff9a8
# 1
# 2
# saving what I have in final dic
# adding some missing stuff to dictionary
# there are some links that have not been turned into text see saved badLinkList for current year
# List was saved under name badLinkList2013.pickle
# stopped the text download for year 2013
# the raw text dictionary with name: nytRawText2013.pickle.pickle HAS BEEN found on local drive. SOMETHING is wrong!!!!

# %%
dataBigger.getDataNytimes(2012, 2013)
# Out:
# START querying the year: 2012
# TOTAL number of queries used: 180
# dealing with month nr.: 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=1&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=3&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=5&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 7
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 8
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 9
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 10
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 11
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 12
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 13
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 14
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 15
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 16
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 17
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 18
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 19
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 20
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 21
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 22
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 23
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 24
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 25
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 26
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 27
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 28
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 29
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 30
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 31
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 32
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 33
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 34
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 35
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 36
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 37
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 38
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 39
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 40
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 41
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 42
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 43
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 44
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 45
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 46
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 47
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 48
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 49
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 50
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 51
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 52
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 53
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 54
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 55
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 56
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 57
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 58
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 59
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 60
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 61
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 62
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 63
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 64
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 65
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 66
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 67
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 68
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 69
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 70
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 71
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 72
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 73
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 74
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 75
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 76
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 77
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 78
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 79
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 80
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 81
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 82
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 83
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 84
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 85
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 86
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 87
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 88
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 89
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 90
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 91
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 92
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 93
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 94
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 95
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 96
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 97
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 98
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 99
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 100
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120101&end_date=20120131&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# File was not found, I will create empty dictionary with name nytSnippets2012
# finished and saved month nr.: 1for year :2012
# dealing with month nr.: 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120201&end_date=20120229&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120201&end_date=20120229&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120201&end_date=20120229&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120201&end_date=20120229&sort=newest&page=1&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120201&end_date=20120229&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120201&end_date=20120229&sort=newest&page=3&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120201&end_date=20120229&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120201&end_date=20120229&sort=newest&page=5&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120201&end_date=20120229&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120201&end_date=20120229&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :7
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120201&end_date=20120229&sort=newest&page=8&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :8
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120201&end_date=20120229&sort=newest&page=9&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :9
# finished and saved month nr.: 2for year :2012
# dealing with month nr.: 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=0&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=1&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=2&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=3&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=4&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=5&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=6&offset=0&api-key=923f498f9f764c228a68501cf957355b
# DOING PAGE NR. :6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 7
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 8
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 9
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 10
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 11
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 12
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 13
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 14
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 15
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 16
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 17
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 18
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 19
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 20
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 21
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 22
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 23
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 24
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 25
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 26
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 27
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 28
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 29
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 30
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=news_desk:("Politics""Economics""Business""Financial""World""Washington""Wealth""Jobs""Society")&begin_date=20120301&end_date=20120331&sort=newest&page=7&offset=0&api-key=923f498f9f764c228a68501cf957355b
# some HTTPError
# TOTAL NR. of ERRORS: 31
# ...
# 1
# 2
# work in progress, step: 305
# working on article with id: 53f956be38f0d84410bcae4f
# 1
# 2
# work in progress, step: 306
# working on article with id: 53f956b038f0d84410bcae4e
# 1
# 2
# work in progress, step: 307
# working on article with id: 53f9572f38f0d84410bcae54
# 1
# 2
# work in progress, step: 308
# working on article with id: 51c37c347e0d9c0839d2a889
# 1
# 2
# work in progress, step: 309
# working on article with id: 53f9532938f0d84410bcae17
# 1
# 2
# work in progress, step: 310
# working on article with id: 53f9541738f0d84410bcae1e
# 1
# 2
# work in progress, step: 311
# working on article with id: 53f9553038f0d84410bcae2b
# 1
# 2
# work in progress, step: 312
# working on article with id: 53f9539f38f0d84410bcae1b
# 1
# 2
# work in progress, step: 313
# working on article with id: 53f9526038f0d84410bcae0f
# 1
# 2
# work in progress, step: 314
# working on article with id: 53f9525338f0d84410bcae0d
# 1
# 2
# work in progress, step: 315
# working on article with id: 53f9519e38f0d84410bcae02
# 1
# 2
# work in progress, step: 316
# working on article with id: 53f94f3d38f0d84410bcade7
# 1
# 2
# work in progress, step: 317
# working on article with id: 53f94f2638f0d84410bcade5
# 1
# 2
# work in progress, step: 318
# working on article with id: 53f94ee838f0d84410bcade1
# 1
# 2
# work in progress, step: 319
# working on article with id: 53f94ecd38f0d84410bcaddf
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 320
# working on article with id: 501eea111c22dfde670b4910
# 1
# 2
# Check the bad link list, because there are 97 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 321
# working on article with id: 53f940b138f0d84410bcad49
# 1
# 2
# work in progress, step: 322
# working on article with id: 501eea1c1c22dfde670b4936
# 1
# 2
# Check the bad link list, because there are 98 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 323
# working on article with id: 53f93d9f38f0d84410bcad22
# 1
# 2
# work in progress, step: 324
# working on article with id: 5016293b1c22dfde670b31fd
# 1
# 2
# work in progress, step: 325
# working on article with id: 5016c3fa1c22dfde670b32ff
# 1
# 2
# work in progress, step: 326
# working on article with id: 501eea1c1c22dfde670b4935
# 1
# 2
# Check the bad link list, because there are 99 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 327
# working on article with id: 5016c3fa1c22dfde670b32fe
# 1
# 2
# work in progress, step: 328
# working on article with id: 501eea111c22dfde670b4909
# 1
# 2
# Check the bad link list, because there are 100 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 329
# working on article with id: 5016c3fa1c22dfde670b32fd
# 1
# 2
# work in progress, step: 330
# working on article with id: 501eea0b1c22dfde670b48f5
# 1
# 2
# Check the bad link list, because there are 101 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 331
# working on article with id: 501eea111c22dfde670b4919
# 1
# 2
# Check the bad link list, because there are 102 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 332
# working on article with id: 501eea0a1c22dfde670b48ed
# 1
# 2
# Check the bad link list, because there are 103 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 333
# working on article with id: 501eea0a1c22dfde670b48eb
# 1
# 2
# Check the bad link list, because there are 104 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 334
# working on article with id: 53f950cb38f0d84410bcadf8
# 1
# 2
# work in progress, step: 335
# working on article with id: 51c37bdc7e0d9c0839d2a87f
# 1
# 2
# work in progress, step: 336
# working on article with id: 53f94c1238f0d84410bcadcb
# 1
# 2
# work in progress, step: 337
# working on article with id: 53f94cc838f0d84410bcadd0
# 1
# 2
# work in progress, step: 338
# working on article with id: 53f94b2a38f0d84410bcadc1
# 1
# 2
# work in progress, step: 339
# working on article with id: 51c37bb57e0d9c0839d2a879
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 340
# working on article with id: 53f94ceb38f0d84410bcadd1
# 1
# 2
# work in progress, step: 341
# working on article with id: 515d9e58cf28d0219d0009fe
# 1
# 2
# work in progress, step: 342
# working on article with id: 53f94c1338f0d84410bcadcc
# 1
# 2
# work in progress, step: 343
# working on article with id: 515d9e5dcf28d0219d000a0e
# 1
# 2
# work in progress, step: 344
# working on article with id: 53f949a538f0d84410bcadb6
# 1
# 2
# work in progress, step: 345
# working on article with id: 53f9499638f0d84410bcadb5
# 1
# 2
# work in progress, step: 346
# working on article with id: 53f948ca38f0d84410bcada8
# 1
# 2
# work in progress, step: 347
# working on article with id: 53f94adf38f0d84410bcadbe
# 1
# 2
# work in progress, step: 348
# working on article with id: 53f94ab438f0d84410bcadbd
# 1
# 2
# work in progress, step: 349
# working on article with id: 53f9499438f0d84410bcadb4
# 1
# 2
# work in progress, step: 350
# working on article with id: 53f9490f38f0d84410bcadad
# 1
# 2
# work in progress, step: 351
# working on article with id: 53f9311638f0d84410bcac8b
# 1
# 2
# work in progress, step: 352
# working on article with id: 53f933b938f0d84410bcacac
# 1
# 2
# work in progress, step: 353
# working on article with id: 53f9356b38f0d84410bcacc1
# 1
# 2
# work in progress, step: 354
# working on article with id: 53f930e038f0d84410bcac87
# 1
# 2
# work in progress, step: 355
# working on article with id: 53f9312238f0d84410bcac8c
# 1
# 2
# work in progress, step: 356
# working on article with id: 501d942e1c22dfde670b4648
# 1
# 2
# Check the bad link list, because there are 105 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 357
# working on article with id: 53f9313d38f0d84410bcac8e
# 1
# 2
# work in progress, step: 358
# working on article with id: 53f9328f38f0d84410bcac9f
# 1
# 2
# work in progress, step: 359
# working on article with id: 53f930d438f0d84410bcac86
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 360
# working on article with id: 53f9307338f0d84410bcac7f
# 1
# 2
# work in progress, step: 361
# working on article with id: 53f9308f38f0d84410bcac81
# 1
# 2
# work in progress, step: 362
# working on article with id: 53f9310c38f0d84410bcac8a
# 1
# 2
# work in progress, step: 363
# working on article with id: 53f9327f38f0d84410bcac9e
# 1
# 2
# work in progress, step: 364
# working on article with id: 53f9354738f0d84410bcacbf
# 1
# 2
# work in progress, step: 365
# working on article with id: 53f9323538f0d84410bcac98
# 1
# 2
# work in progress, step: 366
# working on article with id: 53f9326738f0d84410bcac9c
# 1
# 2
# work in progress, step: 367
# working on article with id: 53f9327538f0d84410bcac9d
# 1
# 2
# work in progress, step: 368
# working on article with id: 53f9316838f0d84410bcac92
# 1
# 2
# work in progress, step: 369
# working on article with id: 53f930ef38f0d84410bcac88
# 1
# 2
# work in progress, step: 370
# working on article with id: 53f934ac38f0d84410bcacba
# 1
# 2
# work in progress, step: 371
# working on article with id: 53f9358738f0d84410bcacc2
# 1
# 2
# work in progress, step: 372
# working on article with id: 53f9314938f0d84410bcac8f
# 1
# 2
# work in progress, step: 373
# working on article with id: 53f9324038f0d84410bcac99
# 1
# 2
# work in progress, step: 374
# working on article with id: 53f934ca38f0d84410bcacbb
# 1
# 2
# work in progress, step: 375
# working on article with id: 501d94411c22dfde670b465a
# 1
# 2
# Check the bad link list, because there are 106 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 376
# working on article with id: 53f9309b38f0d84410bcac83
# 1
# 2
# work in progress, step: 377
# working on article with id: 53f931fa38f0d84410bcac95
# 1
# 2
# work in progress, step: 378
# working on article with id: 501d94341c22dfde670b4651
# 1
# 2
# Check the bad link list, because there are 107 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 379
# working on article with id: 53f9308438f0d84410bcac80
# 1
# 2
# adding some missing stuff to dictionary
# work in progress, step: 380
# working on article with id: 53f9313038f0d84410bcac8d
# 1
# 2
# work in progress, step: 381
# working on article with id: 53f9325b38f0d84410bcac9b
# 1
# 2
# work in progress, step: 382
# working on article with id: 53f9334138f0d84410bcaca7
# 1
# 2
# work in progress, step: 383
# working on article with id: 53f9355438f0d84410bcacc0
# 1
# 2
# work in progress, step: 384
# working on article with id: 515d9e75cf28d0219d000a4b
# 1
# 2
# work in progress, step: 385
# working on article with id: 501c4be61c22dfde670b4330
# 1
# 2
# Check the bad link list, because there are 108 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 386
# working on article with id: 501c4be61c22dfde670b4333
# 1
# 2
# Check the bad link list, because there are 109 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 387
# working on article with id: 501c4be71c22dfde670b433e
# 1
# 2
# Check the bad link list, because there are 110 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 388
# working on article with id: 501c4be61c22dfde670b432f
# 1
# 2
# Check the bad link list, because there are 111 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 389
# working on article with id: 5040d37e1c22dfde670b7f2f
# 1
# 2
# Check the bad link list, because there are 112 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 390
# working on article with id: 5040b0521c22dfde670b7f10
# 1
# 2
# work in progress, step: 391
# working on article with id: 505103251c22dfde670c7ff5
# 1
# 2
# Check the bad link list, because there are 113 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 392
# working on article with id: 505103251c22dfde670c7fee
# 1
# 2
# Check the bad link list, because there are 114 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 393
# working on article with id: 505103251c22dfde670c7ff4
# 1
# 2
# Check the bad link list, because there are 115 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 394
# working on article with id: 505103241c22dfde670c7fe0
# 1
# 2
# Check the bad link list, because there are 116 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 395
# working on article with id: 505103251c22dfde670c7fec
# 1
# 2
# Check the bad link list, because there are 117 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 396
# working on article with id: 505103241c22dfde670c7fdc
# 1
# 2
# Check the bad link list, because there are 118 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 397
# working on article with id: 505103321c22dfde670c806f
# 1
# 2
# Check the bad link list, because there are 119 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 398
# working on article with id: 5051032a1c22dfde670c8039
# 1
# 2
# Check the bad link list, because there are 120 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 399
# working on article with id: 53fa6be538f0d8431914d7b7
# 1
# 2
# Check the bad link list, because there are 121 already and one was just added! It is possible that there is another textClass among them or something else is not working properly.
# continue
# work in progress, step: 400
# working on article with id: 505103321c22dfde670c8070
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-f306036d0d1e> in <module>()
# ----> 1 dataBigger.getDataNytimes(2012, 2013)
#
# <ipython-input-1-1b16f622152c> in getDataNytimes(self, startYear, endYear)
#     534                         print('the raw text dictionary with name: ' + nameOfRawTextDictionary + '.pickle' +
#     535                               ' has not been found on local drive. I will proceed to download it.')
# --> 536                         badLinkList = self.__getNytText('nytRawText', 'nytSnippets', year)
#     537                         print('stopped the text download for year ' + str(year))
#     538                     else:
#
# <ipython-input-1-1b16f622152c> in __getNytText(self, nameOfTextDictOnDisk, nameOfUrlLinksDictionary, year)
#     454         if len(urlDic) > 0:
#     455             print('downloading the Nyt for the Url dictionary ' + nameOfUrlLinksDictionary)
# --> 456             badLinkList = self.__downloadNytText(urlDic, nameOfTextDictOnDisk)
#     457             if len(badLinkList) > 0:
#     458                 print('there are some links that have not been turned into text see saved badLinkList for current year')
#
# <ipython-input-1-1b16f622152c> in __downloadNytText(self, urlDic, nameOfFile)
#     390
#     391                     # print(urlDic[articleKey])
# --> 392                     text = self.__getText(urlDic[articleKey], badLinkList, 2)
#     393                     # print(text)
#     394                     counter += 1
#
# <ipython-input-1-1b16f622152c> in __getText(self, link, badLinkList, numberOfTextClasses)
#     339
#     340         try:
# --> 341             req = urllib.request.Request(link, None)
#     342             cj = CookieJar()
#     343             opener = urllib.request.build_opener(urllib.request.HTTPCookieProcessor(cj))
#
# /Users/Pipjak/anaconda/envs/py36/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     327                  origin_req_host=None, unverifiable=False,
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#     331         self.unredirected_hdrs = {}
#
# /Users/Pipjak/anaconda/envs/py36/lib/python3.6/urllib/request.py in full_url(self, url)
#     353         self._full_url = unwrap(url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#     357     @full_url.deleter
#
# /Users/Pipjak/anaconda/envs/py36/lib/python3.6/urllib/request.py in _parse(self)
#     382         self.type, rest = splittype(self._full_url)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#     386         if self.host:
#
# ValueError: unknown url type: '/data/daily/2012/08/31/520098.sgml'
