# %%
from bs4 import BeautifulSoup as bs

import json
import re
import os
import time
import random
import datetime
import calendar
import logging

import urllib
import urllib.request
from urllib.error import HTTPError

import sklearn
import matplotlib

import numpy as np
import pandas as pd
import sklearn.preprocessing as prep



import requests
import html.parser
from requests.exceptions import HTTPError
from socket import error as SocketError
from http.cookiejar import CookieJar

import feedparser
import pickle

# %%
import langdetect

# %%
langdetect.detect(fakeKaggle.ix[450,'text'])
# Out:
# 'en'

# %%
fak1 = 'http://www.infowars.com'
fak2 = 'http://www.prntly.com'
fak3 = 'http://www.infowars.com/category/us-news'

# %%
queryFakeNewsUrl(fak3)

# %%
def queryFakeNewsUrl(url):
    cj = CookieJar()
    opener = urllib.request.build_opener(urllib.request.HTTPCookieProcessor(cj))
    response = opener.open(url)
    rd = response.read()
    return bs(rd, "html.parser")

# %%
def openList(nameOfSavedList):
    try:
        with open(nameOfSavedList + '.pickle', 'rb') as handle:
            return pickle.load(handle)
    except FileNotFoundError:
        print("File was not found, I will create empty dictionary with name " + nameOfSavedDictionary)
        createEmptyList(nameOfSavedList)
        return openDict(nameOfSavedList)

# %%
def createEmptyList(nameOfList):
    with open(nameOfList + '.pickle', 'wb') as handle:
            pickle.dump({}, handle)

# %%
def saveListToFile(listToSave, listNameOnDisc):
    with open(name + '.pickle', 'wb') as handle:
        pickle.dump(dictionary, handle)

# %%
def extratctLinks(beautifulSoup, nameOfLinkListOnDrive, fakeNewsSource, linkClass):
    links = []
    if fakeNewsSource=='http://www.infowars.com' and linkClass==1:
        for txt in beautifulSoup.find_all('a', class_='disqus-comment-count'):
            potentialLink = txt.attrs['href']
            
            # add to a list of Links
            if potentialLink not in links:
                links.append(potentialLink)
        
        # saving news into the Locally saved list of fake news
        lst = openList('fakeNewsList')
        # extending the original list
        lst.extend(links)
        
        # note this is potentially dangerous operation since it rewrites the original file
        # should not be here because the new stuff only extends the old one
        saveListToFile(lst,'fakeNewsList')

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  '.idea',
#  '.ipynb_checkpoints',
#  '__pycache__',
#  'dirty_data_code_NYT.py',
#  'fake.csv',
#  'FakeData.ipynb',
#  'FakeData.py',
#  'getting_data.ipynb',
#  'kucapaca.pickle',
#  'newDict.pickle',
#  'nyt.csv',
#  'nyt.jsongetTimesArticles_testing.log',
#  'NytData.py',
#  'nytRawTestText2016.pickle',
#  'nytRawText2016.pickle',
#  'nytSnippets2016.pickle',
#  'testDic.pickle',
#  'trial.pickle',
#  'trialList.pickle',
#  'trialList1.pickle']

# %%
fakeKaggle = pd.DataFrame.from_csv('fake.csv')

# %%
print(fakeKaggle.ix[6450,'text'])
# Out:
# Whether it's John McCain, Mitt Romney or Donald Trump, Democrats always run 'War on Women' tactic to destroy the Republican candidate
# ...

# %%
pd.__version__
# Out:
# '0.19.2'

# %%
### ok lets filter out the non-english text and text that is very short

# %%
textSample = fakeKaggle.ix[6450,'text']

# %%
len(textSample.split(' '))
# Out:
# 881

# %%
type(fakeKaggle.ix[2,'text'])
# Out:
# str

# %%
df = pd.DataFrame(np.random.randn(5, 3), columns=['a', 'b', 'velocity'])

# %%
mask = (np.sin(df.velocity) / df.ix[:, 0:2].prod(axis=1)) > 0

# %%
type(mask)
# Out:
# pandas.core.series.Series

# %%
data1 = fakeKaggle.ix[:,0:22]

# %%
# this creates a filter that allows only rows with text that: longer than 300 words and is written in 
# English/(or good enough Engrish)
def filt(textSeries, lowerBoundOnText, language='en'):
    mask = []
    counter = 1
    for mmbr in textSeries:
        print(counter)
        if ((len(str(mmbr).split(' '))>=lowerBoundOnText) and (langdetect.detect(str(mmbr))==language)):
            mask.append(True)
        else:
            mask.append(False)
        counter +=1
    return pd.Series(mask)

# %%
mask = filt(data1.text,300)
# Out:
# Print They should pay all the back all the money plus interest. The entire family and everyone who came in with them need to be deported asap. Why did it take two years to bust them?
# Here we go again …another group stealing from the government and taxpayers! A group of Somalis stole over four million in government benefits over just 10 months!
# We’ve reported on numerous cases like this one where the Muslim refugees/immigrants commit fraud by scamming our system…It’s way out of control! More Related
# Why Did Attorney General Loretta Lynch Plead The Fifth? Barracuda Brigade 2016-10-28 Print The administration is blocking congressional probe into cash payments to Iran. Of course she needs to plead the 5th. She either can’t recall, refuses to answer, or just plain deflects the question. Straight up corruption at its finest!
# ...

# %%
## in this I am subsetting the data in a way it is longer than 300 words and is written in English/Engrish
fakeEnglishData = fakeKaggle[fakeKaggle.apply(lambda x: filt(x, 300), axis=1)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-133018b45fb4> in <module>()
#       1 ## in this I am subsetting the data in a way it is longer than 300 words and is written in English/Engrish
# ----> 2 fakeEnglishData = fakeKaggle[fakeKaggle.apply(lambda x: filt(x, 300), axis=1)]
#
# /Users/Pipjak/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4150                     if reduce is None:
#    4151                         reduce = True
# -> 4152                     return self._apply_standard(f, axis, reduce=reduce)
#    4153             else:
#    4154                 return self._apply_broadcast(f, axis)
#
# /Users/Pipjak/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
# ...
